# %% [markdown]
# Create a new Jupyter notebook in Google Colab. For each of the following, create a notebook cell, load the datasource into a DataFrame, and run df.info() and df.head() to orient yourself to the data.

# %%
import numpy as np
import pandas as pd

# %%
#Load csv dataset into a pandas dataframe and read head (first five entries).

nyc_df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-analytics-bootcamp/nyc_baby_names.csv')
nyc_df.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    Count  Rank Gender.1                 Ethnicity.1 Child's First Name.1  \
# 0    119     1   Female  Asian And Pacific Islander               Sophia
# 1    106     2   Female  Asian And Pacific Islander                Chloe
# 2     93     3   Female  Asian And Pacific Islander                Emily
# 3     89     4   Female  Asian And Pacific Islander               Olivia
# 4     75     5   Female  Asian And Pacific Islander                 Emma
#
#              Sub1                        Sub2  Unnamed: 11
# ...

# %%
#Get info from nyc_df dataset

nyc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11345 entries, 0 to 11344
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year of Birth         11345 non-null  int64
#  1   Gender                11345 non-null  object
#  2   Ethnicity             11345 non-null  object
#  3   Child's First Name    11345 non-null  object
#  4   Count                 11345 non-null  int64
#  5   Rank                  11345 non-null  int64
#  6   Gender.1              11345 non-null  object
#  7   Ethnicity.1           11345 non-null  object
#  8   Child's First Name.1  11345 non-null  object
#  9   Sub1                  11345 non-null  object
#  10  Sub2                  11345 non-null  object
#  11  Unnamed: 11           0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 1.0+ MB

# %%
#Load json dataset into a pandas dataframe and read head (first five entries).

tweets_df = pd.read_json('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-analytics-bootcamp/tweets.json')
tweets_df.head(10)
# Out:
#                    id                                           entities  \
# 0  815449933453127681  {'hashtags': [], 'user_mentions': [{'id': 5254...
# 1  815449868739211265  {'hashtags': [{'indices': [45, 53], 'text': 'n...
# 2  815433444591304704  {'hashtags': [], 'user_mentions': [{'id': 3934...
# 3  815433217595547648  {'hashtags': [], 'user_mentions': [{'id': 2073...
# 4  815432169464197121  {'hashtags': [{'indices': [38, 44], 'text': 'P...
# 5  815422340540547073  {'hashtags': [{'indices': [18, 31], 'text': 'H...
# 6  815271067749060609  {'hashtags': [], 'user_mentions': [{'id': 2507...
# 7  815270850916208644  {'hashtags': [], 'user_mentions': [{'id': 3934...
# 8  815185071317676033  {'hashtags': [], 'user_mentions': [], 'urls': ...
# 9  814958820980039681  {'hashtags': [], 'user_mentions': [{'id': 7592...
#
#    is_quote_status                                               text  \
# 0            False  RT @IvankaTrump: 2016 has been one of the most...
# ...

# %%
#Get info from nyc_df dataset

tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1018 non-null   int64
#  1   entities                   1018 non-null   object
#  2   is_quote_status            1018 non-null   bool
#  3   text                       1018 non-null   object
#  4   favorited                  1018 non-null   bool
#  5   source                     1018 non-null   object
#  6   truncated                  1018 non-null   bool
#  7   created_at                 1018 non-null   datetime64[ns, UTC]
#  8   user                       1018 non-null   object
#  9   geo                        3 non-null      object
#  10  in_reply_to_user_id_str    1 non-null      float64
#  11  coordinates                3 non-null      object
#  12  in_reply_to_user_id        1 non-null      float64
# ...
