# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Introduction
#
# In this project, we will attempt to greate a Cycle Generative Adversarial Network (cycleGAN) in order to manipulate facial images. We will attempt to change the gender for a set of images.

# %% [markdown]
# Our first step is to load the neccessary libraries we will be using for the entire process.

# %%
#Loading the neccessary libraries
# %matplotlib inline

import os, random, cv2, glob, itertools, shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable

import torchvision
from torchvision import datasets, transforms, utils
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
conda install pytorch==1.6.0 torchvision==0.7.0 -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/140 [00:00<?, ?it/s]
# Examining pandas=0.24.2:   0%|          | 0/140 [00:00<?, ?it/s]
# Examining @/win-64::__cuda==11.1=0:   1%|          | 1/140 [00:00<00:25,  5.35it/s]
# Examining @/win-64::__cuda==11.1=0:   1%|1         | 2/140 [00:00<00:12, 10.64it/s]
# Examining zstd:   1%|1         | 2/140 [00:00<00:12, 10.64it/s]
# Examining mkl:   2%|2         | 3/140 [00:00<00:12, 10.64it/s]
# Examining certifi:   3%|2         | 4/140 [00:00<00:12, 10.64it/s]
# Examining pip=19.0:   4%|3         | 5/140 [00:00<00:12, 10.64it/s]
# Examining pip=19.0:   4%|4         | 6/140 [00:00<00:11, 11.21it/s]
# Examining jpeg:   4%|4         | 6/140 [00:00<00:11, 11.21it/s]
# Examining jpeg:   5%|5         | 7/140 [00:00<00:16,  7.91it/s]
# Examining prompt_toolkit:   5%|5         | 7/140 [00:00<00:16,  7.91it/s]
# Examining msys2-conda-epoch:   6%|5         | 8/140 [00:01<00:16,  7.91it/s]
# Examining msys2-conda-epoch:   6%|6         | 9/140 [00:01<00:18,  7.10it/s]
# Examining requests:   6%|6         | 9/140 [00:01<00:18,  7.10it/s]
# Examining zeromq:   7%|7         | 10/140 [00:01<00:18,  7.10it/s]
# Examining zeromq:   8%|7         | 11/140 [00:01<00:22,  5.61it/s]
# Examining mkl_random:   8%|7         | 11/140 [00:01<00:22,  5.61it/s]
# Examining jupyterlab_pygments:   9%|8         | 12/140 [00:02<00:22,  5.61it/s]
# Examining jupyterlab_pygments:   9%|9         | 13/140 [00:02<00:40,  3.16it/s]
# Examining ipywidgets:   9%|9         | 13/140 [00:02<00:40,  3.16it/s]
# Examining cryptography:  10%|#         | 14/140 [00:06<00:39,  3.16it/s]
# Examining cryptography:  11%|#         | 15/140 [00:06<01:32,  1.35it/s]
# Examining libuv:  11%|#         | 15/140 [00:07<01:32,  1.35it/s]
# Examining libuv:  11%|#1        | 16/140 [00:07<01:55,  1.07it/s]
# Examining pyzmq:  11%|#1        | 16/140 [00:07<01:55,  1.07it/s]
# Examining defusedxml:  12%|#2        | 17/140 [00:07<01:54,  1.07it/s]
# Examining defusedxml:  13%|#2        | 18/140 [00:07<01:23,  1.46it/s]
# Examining widgetsnbextension:  13%|#2        | 18/140 [00:07<01:23,  1.46it/s]
# Examining dask-core:  14%|#3        | 19/140 [00:11<01:22,  1.46it/s]
# Examining dask-core:  14%|#4        | 20/140 [00:11<01:53,  1.05it/s]
# Examining freetype:  14%|#4        | 20/140 [00:11<01:53,  1.05it/s]
# Examining freetype:  15%|#5        | 21/140 [00:11<01:50,  1.08it/s]
# Examining pyrsistent:  15%|#5        | 21/140 [00:11<01:50,  1.08it/s]
# Examining six:  16%|#5        | 22/140 [00:12<01:49,  1.08it/s]
# Examining six:  16%|#6        | 23/140 [00:12<01:19,  1.48it/s]
# Examining mkl_fft:  16%|#6        | 23/140 [00:12<01:19,  1.48it/s]
# Examining mkl_fft:  17%|#7        | 24/140 [00:12<00:58,  1.97it/s]
# Examining notebook:  17%|#7        | 24/140 [00:15<00:58,  1.97it/s]
# Examining notebook:  18%|#7        | 25/140 [00:15<02:37,  1.37s/it]
# Examining jupyter_core:  18%|#7        | 25/140 [00:22<02:37,  1.37s/it]
# Examining jupyter_core:  19%|#8        | 26/140 [00:22<05:34,  2.93s/it]
# Examining blas:  19%|#8        | 26/140 [00:22<05:34,  2.93s/it]
# Examining blas:  19%|#9        | 27/140 [00:22<03:57,  2.10s/it]
# Examining wheel:  19%|#9        | 27/140 [00:22<03:57,  2.10s/it]
# Examining python-dateutil:  20%|##        | 28/140 [00:23<03:54,  2.10s/it]
# Examining python-dateutil:  21%|##        | 29/140 [00:23<02:57,  1.60s/it]
# Examining torchaudio:  21%|##        | 29/140 [00:23<02:57,  1.60s/it]
# Examining tornado:  21%|##1       | 30/140 [00:23<02:55,  1.60s/it]
# Examining tornado:  22%|##2       | 31/140 [00:23<02:03,  1.13s/it]
# Examining attrs:  22%|##2       | 31/140 [00:23<02:03,  1.13s/it]
# Examining attrs:  23%|##2       | 32/140 [00:23<01:30,  1.20it/s]
# Examining bleach:  23%|##2       | 32/140 [00:23<01:30,  1.20it/s]
# Examining bleach:  24%|##3       | 33/140 [00:23<01:07,  1.59it/s]
# Examining pysocks:  24%|##3       | 33/140 [00:24<01:07,  1.59it/s]
# Examining pysocks:  24%|##4       | 34/140 [00:24<01:07,  1.58it/s]
# Examining ipython_genutils:  24%|##4       | 34/140 [00:24<01:07,  1.58it/s]
# Examining colorama:  25%|##5       | 35/140 [00:24<01:06,  1.58it/s]
# Examining argon2-cffi:  26%|##5       | 36/140 [00:24<01:05,  1.58it/s]
# Examining argon2-cffi:  26%|##6       | 37/140 [00:24<00:47,  2.19it/s]
# Examining lz4-c:  26%|##6       | 37/140 [00:24<00:47,  2.19it/s]
# Examining vs2015_runtime:  27%|##7       | 38/140 [00:24<00:46,  2.19it/s]
# Examining libpng:  28%|##7       | 39/140 [00:24<00:46,  2.19it/s]
# Examining cffi:  29%|##8       | 40/140 [00:24<00:45,  2.19it/s]
# Examining jedi:  29%|##9       | 41/140 [00:24<00:45,  2.19it/s]
# Examining jedi:  30%|###       | 42/140 [00:24<00:32,  3.01it/s]
# Examining markupsafe:  30%|###       | 42/140 [00:24<00:32,  3.01it/s]
# Examining m2w64-gcc-libgfortran:  31%|###       | 43/140 [00:24<00:32,  3.01it/s]
# Examining m2w64-gcc-libgfortran:  31%|###1      | 44/140 [00:24<00:25,  3.83it/s]
# Examining entrypoints:  31%|###1      | 44/140 [00:24<00:25,  3.83it/s]
# Examining pywin32:  32%|###2      | 45/140 [00:24<00:24,  3.83it/s]
# Examining mkl-service:  33%|###2      | 46/140 [00:24<00:24,  3.83it/s]
# Examining sqlite:  34%|###3      | 47/140 [00:25<00:24,  3.83it/s]
# Examining sqlite:  34%|###4      | 48/140 [00:25<00:18,  4.93it/s]
# Examining jsonschema:  34%|###4      | 48/140 [00:25<00:18,  4.93it/s]
# Examining yaml:  35%|###5      | 49/140 [00:25<00:18,  4.93it/s]
# Examining yaml:  36%|###5      | 50/140 [00:25<00:19,  4.55it/s]
# Examining nbconvert:  36%|###5      | 50/140 [00:25<00:19,  4.55it/s]
# Examining pycparser:  36%|###6      | 51/140 [00:26<00:19,  4.55it/s]
# Examining pycparser:  37%|###7      | 52/140 [00:26<00:24,  3.56it/s]
# Examining testpath:  37%|###7      | 52/140 [00:26<00:24,  3.56it/s]
# Examining cytoolz:  38%|###7      | 53/140 [00:26<00:24,  3.56it/s]
# Examining m2w64-gcc-libs:  39%|###8      | 54/140 [00:26<00:24,  3.56it/s]
# Examining m2w64-gcc-libs:  39%|###9      | 55/140 [00:26<00:17,  4.73it/s]
# Examining plotly=3.7.0:  39%|###9      | 55/140 [00:26<00:17,  4.73it/s]
# Examining send2trash:  40%|####      | 56/140 [00:26<00:17,  4.73it/s]
# Examining pickleshare:  41%|####      | 57/140 [00:26<00:17,  4.73it/s]
# Examining seaborn:  41%|####1     | 58/140 [00:26<00:17,  4.73it/s]
# Examining libtiff:  42%|####2     | 59/140 [00:28<00:17,  4.73it/s]
# Examining libtiff:  43%|####2     | 60/140 [00:28<00:21,  3.69it/s]
# Examining scikit-learn=0.20.3:  43%|####2     | 60/140 [00:28<00:21,  3.69it/s]
# Examining jupyter_console:  44%|####3     | 61/140 [00:28<00:21,  3.69it/s]
# Examining jupyter_console:  44%|####4     | 62/140 [00:28<00:16,  4.59it/s]
# Examining nbclient:  44%|####4     | 62/140 [00:29<00:16,  4.59it/s]
# Examining nbclient:  45%|####5     | 63/140 [00:29<00:25,  3.07it/s]
# Examining brotlipy:  45%|####5     | 63/140 [00:29<00:25,  3.07it/s]
# Examining numpy-base:  46%|####5     | 64/140 [00:29<00:24,  3.07it/s]
# Examining nbformat:  46%|####6     | 65/140 [00:30<00:24,  3.07it/s]
# Examining nbformat:  47%|####7     | 66/140 [00:30<00:23,  3.10it/s]
# Examining pygments:  47%|####7     | 66/140 [00:30<00:23,  3.10it/s]
# Examining pygments:  48%|####7     | 67/140 [00:30<00:21,  3.41it/s]
# Examining ninja:  48%|####7     | 67/140 [00:31<00:21,  3.41it/s]
# Examining ninja:  49%|####8     | 68/140 [00:31<00:25,  2.87it/s]
# Examining ipython:  49%|####8     | 68/140 [00:31<00:25,  2.87it/s]
# Examining zlib:  49%|####9     | 69/140 [00:33<00:24,  2.87it/s]
# Examining zlib:  50%|#####     | 70/140 [00:33<00:43,  1.60it/s]
# Examining importlib_metadata:  50%|#####     | 70/140 [00:33<00:43,  1.60it/s]
# Examining ipykernel:  51%|#####     | 71/140 [00:33<00:43,  1.60it/s]
# Examining ipykernel:  51%|#####1    | 72/140 [00:33<00:32,  2.12it/s]
# Examining pandoc:  51%|#####1    | 72/140 [00:37<00:32,  2.12it/s]
# Examining pandoc:  52%|#####2    | 73/140 [00:37<01:32,  1.38s/it]
# Examining cycler:  52%|#####2    | 73/140 [00:37<01:32,  1.38s/it]
# Examining cloudpickle:  53%|#####2    | 74/140 [00:37<01:31,  1.38s/it]
# Examining qtpy:  54%|#####3    | 75/140 [00:37<01:29,  1.38s/it]
# Examining qtpy:  54%|#####4    | 76/140 [00:37<01:03,  1.00it/s]
# Examining python=3.7.3:  54%|#####4    | 76/140 [00:37<01:03,  1.00it/s]
# Examining python=3.7.3:  55%|#####5    | 77/140 [00:37<00:47,  1.33it/s]
# Examining wincertstore:  55%|#####5    | 77/140 [00:37<00:47,  1.33it/s]
# Examining idna:  56%|#####5    | 78/140 [00:37<00:46,  1.33it/s]
# Examining parso:  56%|#####6    | 79/140 [00:37<00:45,  1.33it/s]
# Examining parso:  57%|#####7    | 80/140 [00:37<00:32,  1.85it/s]
# Examining libsodium:  57%|#####7    | 80/140 [00:38<00:32,  1.85it/s]
# Examining olefile:  58%|#####7    | 81/140 [00:38<00:31,  1.85it/s]
# Examining olefile:  59%|#####8    | 82/140 [00:38<00:23,  2.43it/s]
# Examining pytorch==1.6.0:  59%|#####8    | 82/140 [00:38<00:23,  2.43it/s]
# Examining openssl:  59%|#####9    | 83/140 [00:39<00:23,  2.43it/s]
# Examining openssl:  60%|######    | 84/140 [00:39<00:23,  2.35it/s]
# Examining retrying:  60%|######    | 84/140 [00:39<00:23,  2.35it/s]
# Examining tk:  61%|######    | 85/140 [00:39<00:23,  2.35it/s]
# Examining prometheus_client:  61%|######1   | 86/140 [00:39<00:22,  2.35it/s]
# Examining pyqt:  62%|######2   | 87/140 [00:39<00:22,  2.35it/s]
# Examining pyqt:  63%|######2   | 88/140 [00:39<00:17,  2.96it/s]
# Examining vc:  63%|######2   | 88/140 [00:39<00:17,  2.96it/s]
# Examining vc:  64%|######3   | 89/140 [00:39<00:13,  3.65it/s]
# Examining networkx:  64%|######3   | 89/140 [00:39<00:13,  3.65it/s]
# Examining win_inet_pton:  64%|######4   | 90/140 [00:39<00:13,  3.65it/s]
# Examining win_inet_pton:  65%|######5   | 91/140 [00:39<00:11,  4.22it/s]
# Examining intel-openmp:  65%|######5   | 91/140 [00:40<00:11,  4.22it/s]
# Examining webencodings:  66%|######5   | 92/140 [00:40<00:11,  4.22it/s]
# Examining jupyter=1.0.0:  66%|######6   | 93/140 [00:40<00:11,  4.22it/s]
# Examining prompt-toolkit:  67%|######7   | 94/140 [00:41<00:10,  4.22it/s]
# Examining prompt-toolkit:  68%|######7   | 95/140 [00:41<00:13,  3.34it/s]
# Examining pyopenssl:  68%|######7   | 95/140 [00:41<00:13,  3.34it/s]
# Examining scipy:  69%|######8   | 96/140 [00:42<00:13,  3.34it/s]
# Examining scipy:  69%|######9   | 97/140 [00:42<00:11,  3.67it/s]
# Examining pillow:  69%|######9   | 97/140 [00:44<00:11,  3.67it/s]
# Examining pillow:  70%|#######   | 98/140 [00:44<00:32,  1.29it/s]
# Examining traitlets:  70%|#######   | 98/140 [00:44<00:32,  1.29it/s]
# Examining traitlets:  71%|#######   | 99/140 [00:44<00:26,  1.55it/s]
# Examining packaging:  71%|#######   | 99/140 [00:44<00:26,  1.55it/s]
# Examining pyyaml:  71%|#######1  | 100/140 [00:44<00:25,  1.55it/s]
# Examining pyyaml:  72%|#######2  | 101/140 [00:44<00:18,  2.09it/s]
# Examining pywavelets:  72%|#######2  | 101/140 [00:44<00:18,  2.09it/s]
# Examining wcwidth:  73%|#######2  | 102/140 [00:45<00:18,  2.09it/s]
# Examining wcwidth:  74%|#######3  | 103/140 [00:45<00:18,  1.99it/s]
# Examining mistune:  74%|#######3  | 103/140 [00:45<00:18,  1.99it/s]
# Examining torchvision==0.7.0:  74%|#######4  | 104/140 [00:45<00:18,  1.99it/s]
# Examining torchvision==0.7.0:  75%|#######5  | 105/140 [00:45<00:12,  2.71it/s]
# Examining winpty:  75%|#######5  | 105/140 [00:46<00:12,  2.71it/s]
# Examining winpty:  76%|#######5  | 106/140 [00:46<00:14,  2.30it/s]
# Examining m2w64-libwinpthread-git:  76%|#######5  | 106/140 [00:46<00:14,  2.30it/s]
# Examining xz:  76%|#######6  | 107/140 [00:46<00:14,  2.30it/s]
# Examining importlib-metadata:  77%|#######7  | 108/140 [00:46<00:13,  2.30it/s]
# Examining icu:  78%|#######7  | 109/140 [00:46<00:13,  2.30it/s]
# Examining jupyter_client:  79%|#######8  | 110/140 [00:46<00:13,  2.30it/s]
# Examining pandocfilters:  79%|#######9  | 111/140 [00:47<00:12,  2.30it/s]
# Examining pandocfilters:  80%|########  | 112/140 [00:47<00:09,  2.93it/s]
# Examining decorator:  80%|########  | 112/140 [00:47<00:09,  2.93it/s]
# Examining pytz:  81%|########  | 113/140 [00:47<00:09,  2.93it/s]
# Examining zipp:  81%|########1 | 114/140 [00:47<00:08,  2.93it/s]
# Examining zipp:  82%|########2 | 115/140 [00:47<00:06,  3.91it/s]
# Examining typing_extensions:  82%|########2 | 115/140 [00:47<00:06,  3.91it/s]
# Examining async_generator:  83%|########2 | 116/140 [00:47<00:06,  3.91it/s]
# Examining async_generator:  84%|########3 | 117/140 [00:47<00:04,  5.10it/s]
# Examining imageio:  84%|########3 | 117/140 [00:47<00:04,  5.10it/s]
# Examining qt:  84%|########4 | 118/140 [00:49<00:04,  5.10it/s]
# Examining qt:  85%|########5 | 119/140 [00:49<00:07,  2.65it/s]
# Examining backcall:  85%|########5 | 119/140 [00:49<00:07,  2.65it/s]
# Examining qtconsole:  86%|########5 | 120/140 [00:49<00:07,  2.65it/s]
# Examining scikit-image:  86%|########6 | 121/140 [00:50<00:07,  2.65it/s]
# Examining scikit-image:  87%|########7 | 122/140 [00:50<00:06,  2.72it/s]
# Examining urllib3:  87%|########7 | 122/140 [00:55<00:06,  2.72it/s]
# Examining urllib3:  88%|########7 | 123/140 [00:55<00:29,  1.72s/it]
# Examining setuptools:  88%|########7 | 123/140 [00:57<00:29,  1.72s/it]
# Examining setuptools:  89%|########8 | 124/140 [00:57<00:29,  1.84s/it]
# Examining sip:  89%|########8 | 124/140 [00:58<00:29,  1.84s/it]
# Examining sip:  89%|########9 | 125/140 [00:58<00:24,  1.64s/it]
# Examining jinja2:  89%|########9 | 125/140 [00:58<00:24,  1.64s/it]
# Examining jinja2:  90%|######### | 126/140 [00:58<00:16,  1.18s/it]
# Examining toolz:  90%|######### | 126/140 [00:58<00:16,  1.18s/it]
# Examining toolz:  91%|######### | 127/140 [00:58<00:12,  1.03it/s]
# Examining cudatoolkit=11.0:  91%|######### | 127/140 [00:58<00:12,  1.03it/s]
# Examining chardet:  91%|#########1| 128/140 [00:58<00:11,  1.03it/s]
# Examining matplotlib=3.0.3:  92%|#########2| 129/140 [00:58<00:10,  1.03it/s]
# Examining icc_rt:  93%|#########2| 130/140 [00:59<00:09,  1.03it/s]
# Examining icc_rt:  94%|#########3| 131/140 [00:59<00:06,  1.42it/s]
# Examining nest-asyncio:  94%|#########3| 131/140 [00:59<00:06,  1.42it/s]
# Examining pyparsing:  94%|#########4| 132/140 [00:59<00:05,  1.42it/s]
# Examining pywinpty:  95%|#########5| 133/140 [00:59<00:04,  1.42it/s]
# Examining pywinpty:  96%|#########5| 134/140 [00:59<00:03,  1.94it/s]
# Examining numpy=1.16.2:  96%|#########5| 134/140 [00:59<00:03,  1.94it/s]
# Examining numpy=1.16.2:  96%|#########6| 135/140 [00:59<00:02,  2.46it/s]
# Examining m2w64-gcc-libs-core:  96%|#########6| 135/140 [00:59<00:02,  2.46it/s]
# Examining ca-certificates:  97%|#########7| 136/140 [00:59<00:01,  2.46it/s]
# Examining terminado:  98%|#########7| 137/140 [00:59<00:01,  2.46it/s]
# Examining kiwisolver:  99%|#########8| 138/140 [00:59<00:00,  2.46it/s]
# Examining kiwisolver:  99%|#########9| 139/140 [00:59<00:00,  3.28it/s]
# Examining m2w64-gmp:  99%|#########9| 139/140 [00:59<00:00,  3.28it/s]
#
#
# Determining conflicts:   0%|          | 0/140 [00:00<?, ?it/s]
# Examining conflict for pandas scikit-image seaborn:   0%|          | 0/140 [00:00<?, ?it/s]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments mkl_random ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile pytorch retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision importlib-metadata jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   1%|          | 1/140 [00:02<05:51,  2.53s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments mkl_random ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile pytorch retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision importlib-metadata jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   1%|1         | 2/140 [00:02<02:54,  1.26s/it]
# Examining conflict for mkl-service torchvision matplotlib torchaudio imageio numpy pandas numpy-base scipy scikit-image mkl_fft seaborn pytorch mkl mkl_random pywavelets scikit-learn:   1%|1         | 2/140 [00:12<02:54,  1.26s/it]
# Examining conflict for mkl-service torchvision matplotlib torchaudio imageio numpy pandas numpy-base scipy scikit-image mkl_fft seaborn pytorch mkl mkl_random pywavelets scikit-learn:   2%|2         | 3/140 [00:12<08:31,  3.74s/it]
# Examining conflict for matplotlib pandas scikit-image plotly seaborn pytz:   2%|2         | 3/140 [00:17<08:31,  3.74s/it]
# Examining conflict for matplotlib pandas scikit-image plotly seaborn pytz:   3%|2         | 4/140 [00:17<09:38,  4.25s/it]
# Examining conflict for mkl-service torchvision matplotlib imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft mkl_random pywavelets scikit-learn:   3%|2         | 4/140 [00:19<09:38,  4.25s/it]
# Examining conflict for mkl-service torchvision matplotlib imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft mkl_random pywavelets scikit-learn:   4%|3         | 5/140 [00:19<08:17,  3.68s/it]
# Examining conflict for mkl-service torchvision matplotlib imageio numpy pandas scipy scikit-image seaborn pytorch mkl_fft mkl_random pywavelets scikit-learn:   4%|3         | 5/140 [00:26<08:17,  3.68s/it]
# Examining conflict for mkl-service torchvision matplotlib imageio numpy pandas scipy scikit-image seaborn pytorch mkl_fft mkl_random pywavelets scikit-learn:   4%|4         | 6/140 [00:26<09:59,  4.48s/it]
# Examining conflict for pandas zstd certifi pip jpeg prompt_toolkit requests jupyterlab_pygments mkl_random zeromq ipywidgets cryptography libuv pyzmq defusedxml widgetsnbextension dask-core freetype pyrsistent six mkl_fft jupyter_core notebook wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi lz4-c libpng cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema yaml nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn libtiff nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython zlib importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso libsodium olefile pytorch openssl retrying tk prometheus_client pyqt vc networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision winpty xz importlib-metadata icu jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz cudatoolkit chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   4%|4         | 6/140 [00:31<09:59,  4.48s/it]
# Examining conflict for pandas zstd certifi pip jpeg prompt_toolkit requests jupyterlab_pygments mkl_random zeromq ipywidgets cryptography libuv pyzmq defusedxml widgetsnbextension dask-core freetype pyrsistent six mkl_fft jupyter_core notebook wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi lz4-c libpng cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema yaml nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn libtiff nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython zlib importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso libsodium olefile pytorch openssl retrying tk prometheus_client pyqt vc networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision winpty xz importlib-metadata icu jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz cudatoolkit chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   5%|5         | 7/140 [00:31<10:24,  4.70s/it]
# Examining conflict for jupyter_console python-dateutil prompt-toolkit pyopenssl pandas numpy-base scipy nbformat tornado ipython traitlets packaging importlib_metadata bleach ipykernel argon2-cffi prompt_toolkit cycler jupyter_client mkl_random ipywidgets zipp mkl-service cryptography jsonschema qtconsole scikit-image urllib3 nbconvert pytorch testpath notebook matplotlib retrying plotly pyrsistent six pickleshare seaborn mkl_fft jupyter_core nbclient:   5%|5         | 7/140 [00:39<10:24,  4.70s/it]
# Examining conflict for jupyter_console python-dateutil prompt-toolkit pyopenssl pandas numpy-base scipy nbformat tornado ipython traitlets packaging importlib_metadata bleach ipykernel argon2-cffi prompt_toolkit cycler jupyter_client mkl_random ipywidgets zipp mkl-service cryptography jsonschema qtconsole scikit-image urllib3 nbconvert pytorch testpath notebook matplotlib retrying plotly pyrsistent six pickleshare seaborn mkl_fft jupyter_core nbclient:   6%|5         | 8/140 [00:39<12:38,  5.75s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments mkl_random ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi cffi jedi markupsafe pywin32 entrypoints mkl-service jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile pytorch openssl retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision importlib-metadata jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   6%|5         | 8/140 [00:43<12:38,  5.75s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments mkl_random ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi cffi jedi markupsafe pywin32 entrypoints mkl-service jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile pytorch openssl retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision importlib-metadata jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   6%|6         | 9/140 [00:43<11:19,  5.19s/it]
# Examining conflict for pandas zstd certifi pip jpeg prompt_toolkit requests jupyterlab_pygments mkl_random zeromq ipywidgets cryptography libuv pyzmq defusedxml widgetsnbextension dask-core freetype pyrsistent six mkl_fft jupyter_core notebook wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi lz4-c vs2015_runtime libpng cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema yaml nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn libtiff nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython zlib importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso libsodium olefile pytorch openssl retrying tk prometheus_client pyqt vc networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision winpty xz importlib-metadata icu jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz cudatoolkit chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   6%|6         | 9/140 [00:52<11:19,  5.19s/it]
# Examining conflict for pandas zstd certifi pip jpeg prompt_toolkit requests jupyterlab_pygments mkl_random zeromq ipywidgets cryptography libuv pyzmq defusedxml widgetsnbextension dask-core freetype pyrsistent six mkl_fft jupyter_core notebook wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi lz4-c vs2015_runtime libpng cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema yaml nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn libtiff nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython zlib importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso libsodium olefile pytorch openssl retrying tk prometheus_client pyqt vc networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision winpty xz importlib-metadata icu jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz cudatoolkit chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   7%|7         | 10/140 [00:52<13:29,  6.23s/it]
# Examining conflict for mkl-service torchvision matplotlib torchaudio imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft mkl_random pywavelets scikit-learn:   7%|7         | 10/140 [01:00<13:29,  6.23s/it]
# Examining conflict for mkl-service torchvision matplotlib torchaudio imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft mkl_random pywavelets scikit-learn:   8%|7         | 11/140 [01:00<14:45,  6.86s/it]
# Examining conflict for mkl-service torchvision matplotlib torchaudio imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft blas mkl_random pywavelets scikit-learn:   8%|7         | 11/140 [01:02<14:45,  6.86s/it]
# Examining conflict for mkl-service torchvision matplotlib torchaudio imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft blas mkl_random pywavelets scikit-learn:   9%|8         | 12/140 [01:02<11:44,  5.50s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments mkl_random ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi cffi jedi markupsafe pywin32 entrypoints mkl-service jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile pytorch retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision importlib-metadata jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   9%|8         | 12/140 [01:05<11:44,  5.50s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments mkl_random ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil torchaudio tornado attrs bleach pysocks ipython_genutils colorama argon2-cffi cffi jedi markupsafe pywin32 entrypoints mkl-service jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn nbclient jupyter_console scikit-learn brotlipy numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile pytorch retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter prompt-toolkit pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune torchvision importlib-metadata jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet matplotlib nest-asyncio pyparsing pywinpty numpy terminado kiwisolver:   9%|9         | 13/140 [01:05<10:05,  4.77s/it]
# Examining conflict for pandas zstd certifi pip jpeg prompt_toolkit requests jupyterlab_pygments zeromq ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core freetype pyrsistent six mkl_fft jupyter_core notebook wheel python-dateutil tornado attrs bleach pysocks ipython_genutils colorama lz4-c libpng cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema yaml nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn libtiff scikit-learn jupyter_console numpy-base nbformat pygments ninja ipython zlib importlib_metadata ipykernel cycler cloudpickle qtpy wincertstore idna parso libsodium olefile openssl retrying tk prometheus_client pyqt vc networkx win_inet_pton webencodings jupyter pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune xz icu jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet pyparsing pywinpty numpy terminado kiwisolver:   9%|9         | 13/140 [01:10<10:05,  4.77s/it]
# Examining conflict for pandas zstd certifi pip jpeg prompt_toolkit requests jupyterlab_pygments zeromq ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core freetype pyrsistent six mkl_fft jupyter_core notebook wheel python-dateutil tornado attrs bleach pysocks ipython_genutils colorama lz4-c libpng cffi jedi markupsafe pywin32 entrypoints mkl-service sqlite jsonschema yaml nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn libtiff scikit-learn jupyter_console numpy-base nbformat pygments ninja ipython zlib importlib_metadata ipykernel cycler cloudpickle qtpy wincertstore idna parso libsodium olefile openssl retrying tk prometheus_client pyqt vc networkx win_inet_pton webencodings jupyter pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune xz icu jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet pyparsing pywinpty numpy terminado kiwisolver:  10%|#         | 14/140 [01:10<09:57,  4.74s/it]
# Examining conflict for mkl-service torchvision matplotlib imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft icc_rt mkl_random pywavelets scikit-learn:  10%|#         | 14/140 [01:17<09:57,  4.74s/it]
# Examining conflict for mkl-service torchvision matplotlib imageio numpy pandas numpy-base scipy scikit-image seaborn pytorch mkl_fft icc_rt mkl_random pywavelets scikit-learn:  11%|#         | 15/140 [01:17<11:00,  5.29s/it]
# Examining conflict for jupyter_console matplotlib python-dateutil ipykernel pandas qtconsole scikit-image nbconvert jupyter_client seaborn notebook nbclient:  11%|#         | 15/140 [01:22<11:00,  5.29s/it]
# Examining conflict for jupyter_console matplotlib python-dateutil ipykernel pandas qtconsole scikit-image nbconvert jupyter_client seaborn notebook nbclient:  11%|#1        | 16/140 [01:22<11:01,  5.34s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil tornado attrs bleach pysocks ipython_genutils colorama cffi jedi markupsafe pywin32 entrypoints mkl-service jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn scikit-learn jupyter_console numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile openssl retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet pyparsing pywinpty numpy ca-certificates terminado kiwisolver:  11%|#1        | 16/140 [01:25<11:01,  5.34s/it]
# Examining conflict for pandas certifi pip prompt_toolkit requests jupyterlab_pygments ipywidgets cryptography pyzmq defusedxml widgetsnbextension dask-core pyrsistent six mkl_fft notebook jupyter_core wheel python-dateutil tornado attrs bleach pysocks ipython_genutils colorama cffi jedi markupsafe pywin32 entrypoints mkl-service jsonschema nbconvert pycparser testpath cytoolz plotly send2trash pickleshare seaborn scikit-learn jupyter_console numpy-base nbformat pygments ninja ipython importlib_metadata ipykernel cycler cloudpickle qtpy python wincertstore idna parso olefile openssl retrying prometheus_client pyqt networkx win_inet_pton webencodings jupyter pyopenssl scipy pillow traitlets packaging pyyaml pywavelets wcwidth mistune jupyter_client pandocfilters decorator pytz zipp typing_extensions async_generator imageio qt backcall qtconsole scikit-image urllib3 setuptools sip jinja2 toolz chardet pyparsing pywinpty numpy ca-certificates terminado kiwisolver:  12%|#2        | 17/140 [01:25<09:30,  4.64s/it]
# Examining conflict for __cuda:  12%|#2        | 17/140 [01:32<09:30,  4.64s/it]
# Examining conflict for __cuda:  13%|#2        | 18/140 [01:32<10:54,  5.36s/it]
# Examining conflict for pillow zstd libtiff:  13%|#2        | 18/140 [01:32<10:54,  5.36s/it]
# Examining conflict for torchvision matplotlib python sqlite imageio qt scikit-image libpng freetype zlib pyqt zstd pillow seaborn libtiff:  14%|#3        | 19/140 [01:32<10:48,  5.36s/it]
# Examining conflict for pillow zstd libtiff xz:  14%|#4        | 20/140 [01:35<10:43,  5.36s/it]
# Examining conflict for pillow zstd libtiff xz:  15%|#5        | 21/140 [01:35<08:04,  4.07s/it]
# Examining conflict for zstd libtiff lz4-c:  15%|#5        | 21/140 [01:35<08:04,  4.07s/it]
# Examining conflict for mkl-service numpy numpy-base scipy mkl_fft pytorch mkl intel-openmp mkl_random scikit-learn:  16%|#5        | 22/140 [01:35<08:00,  4.07s/it]
# Examining conflict for wheel pygments tornado ipython certifi bleach ipykernel pip jupyter_client requests jsonschema scikit-image urllib3 setuptools jinja2 matplotlib pywinpty plotly terminado networkx notebook:  16%|#6        | 23/140 [01:37<07:56,  4.07s/it]
# Examining conflict for wheel pygments tornado ipython certifi bleach ipykernel pip jupyter_client requests jsonschema scikit-image urllib3 setuptools jinja2 matplotlib pywinpty plotly terminado networkx notebook:  17%|#7        | 24/140 [01:37<05:54,  3.05s/it]
# Examining conflict for wheel jupyter_console python-dateutil prompt-toolkit pyopenssl nbformat pygments traitlets attrs packaging wcwidth certifi bleach colorama prompt_toolkit importlib-metadata jupyter_client cloudpickle qtpy requests pandocfilters jupyterlab_pygments ipywidgets decorator pytz zipp typing_extensions async_generator jsonschema wincertstore imageio idna parso backcall qtconsole urllib3 nbconvert olefile setuptools defusedxml pycparser testpath jinja2 toolz nest-asyncio pyparsing retrying dask-core prometheus_client plotly six seaborn networkx jupyter_core nbclient:  17%|#7        | 24/140 [01:40<05:54,  3.05s/it]
# Examining conflict for wheel jupyter_console python-dateutil prompt-toolkit pyopenssl nbformat pygments traitlets attrs packaging wcwidth certifi bleach colorama prompt_toolkit importlib-metadata jupyter_client cloudpickle qtpy requests pandocfilters jupyterlab_pygments ipywidgets decorator pytz zipp typing_extensions async_generator jsonschema wincertstore imageio idna parso backcall qtconsole urllib3 nbconvert olefile setuptools defusedxml pycparser testpath jinja2 toolz nest-asyncio pyparsing retrying dask-core prometheus_client plotly six seaborn networkx jupyter_core nbclient:  18%|#7        | 25/140 [01:40<05:27,  2.85s/it]
# Examining conflict for wheel matplotlib bleach pywinpty jsonschema wincertstore pip pygments ipython setuptools plotly networkx jinja2:  18%|#7        | 25/140 [01:42<05:27,  2.85s/it]
# Examining conflict for wheel matplotlib bleach pywinpty jsonschema wincertstore pip pygments ipython setuptools plotly networkx jinja2:  19%|#8        | 26/140 [01:42<05:07,  2.69s/it]
# Examining conflict for wheel python pip:  19%|#8        | 26/140 [01:42<05:07,  2.69s/it]
# Examining conflict for wheel python pip:  19%|#9        | 27/140 [01:42<03:49,  2.03s/it]
# Examining conflict for wheel jupyter_console prompt-toolkit nbformat pygments ipython attrs bleach ipykernel pip prompt_toolkit terminado jupyterlab_pygments ipywidgets python jsonschema qtconsole scikit-image nbconvert setuptools jinja2 matplotlib pywinpty plotly seaborn networkx notebook:  19%|#9        | 27/140 [01:42<03:49,  2.03s/it]
# Examining conflict for torchvision imageio qt jpeg scikit-image pyqt pillow libtiff:  20%|##        | 28/140 [01:45<03:47,  2.03s/it]
# Examining conflict for torchvision imageio qt jpeg scikit-image pyqt pillow libtiff:  21%|##        | 29/140 [01:45<03:13,  1.74s/it]
# Examining conflict for jupyter_console jupyter ipykernel prompt_toolkit ipython ipywidgets:  21%|##        | 29/140 [01:46<03:13,  1.74s/it]
# Examining conflict for jupyter_console jupyter ipykernel prompt_toolkit ipython ipywidgets:  21%|##1       | 30/140 [01:46<02:55,  1.60s/it]
# Examining conflict for jupyter_console ipykernel prompt-toolkit prompt_toolkit ipython ipywidgets:  21%|##1       | 30/140 [01:46<02:55,  1.60s/it]
# Examining conflict for jupyter_console ipykernel prompt-toolkit prompt_toolkit ipython ipywidgets:  22%|##2       | 31/140 [01:46<02:14,  1.23s/it]
# Examining conflict for jupyter_console prompt-toolkit prompt_toolkit ipython wcwidth:  22%|##2       | 31/140 [01:47<02:14,  1.23s/it]
# Examining conflict for jupyter_console prompt-toolkit prompt_toolkit ipython wcwidth:  23%|##2       | 32/140 [01:47<01:41,  1.06it/s]
# Examining conflict for jupyter_console jupyter ipykernel prompt-toolkit qtconsole prompt_toolkit pygments nbconvert ipython notebook jupyterlab_pygments ipywidgets:  23%|##2       | 32/140 [01:47<01:41,  1.06it/s]
# Examining conflict for jupyter_console jupyter ipykernel prompt-toolkit qtconsole prompt_toolkit pygments nbconvert ipython notebook jupyterlab_pygments ipywidgets:  24%|##3       | 33/140 [01:47<01:15,  1.43it/s]
# Examining conflict for pywinpty m2w64-libwinpthread-git m2w64-gcc-libs-core m2w64-gcc-libs m2w64-gcc-libgfortran msys2-conda-epoch m2w64-gmp:  24%|##3       | 33/140 [01:47<01:15,  1.43it/s]
# Examining conflict for pywinpty m2w64-libwinpthread-git m2w64-gcc-libs-core m2w64-gcc-libs m2w64-gcc-libgfortran msys2-conda-epoch m2w64-gmp:  24%|##4       | 34/140 [01:47<01:03,  1.68it/s]
# Examining conflict for plotly requests python:  24%|##4       | 34/140 [01:47<01:03,  1.68it/s]
# Examining conflict for pysocks requests urllib3:  25%|##5       | 35/140 [01:47<01:02,  1.68it/s]
# Examining conflict for cryptography pyopenssl idna prometheus_client urllib3 plotly requests:  26%|##5       | 36/140 [01:47<01:02,  1.68it/s]
# Examining conflict for plotly requests urllib3:  26%|##6       | 37/140 [01:47<01:01,  1.68it/s]
# ...
# pywinpty -> winpty[version='>=0.4.3,<1.0a0']
#
# Package colorama conflicts for:
# ipywidgets -> ipython[version='>=4.0.0'] -> colorama
# jupyter_console -> ipython -> colorama
# ipykernel -> ipython[version='>=5.0'] -> colorama
# ipython -> colorama
# colorama
# python=3.7.3 -> pip -> colorama
#
# Package networkx conflicts for:
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
# networkx
#
# Package async_generator conflicts for:
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> async_generator
# async_generator
# nbclient -> async_generator
#
# Package ipython conflicts for:
# ipython
# ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
# jupyter_console -> ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
# jupyter=1.0.0 -> ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
# qtconsole -> ipykernel[version='>=4.1'] -> ipython[version='>=4.0.0|>=4.0|>=5.0']
# notebook -> ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
# jupyter_console -> ipython
# ipywidgets -> ipython[version='>=4.0.0']
# ipywidgets -> ipykernel[version='>=4.5.1'] -> ipython[version='>=4.0|>=5.0']
#
# Package attrs conflicts for:
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> attrs[version='>=17.4.0']
# prometheus_client -> twisted -> attrs[version='>=17.4.0']
# jsonschema -> attrs[version='>=17.4.0']
# attrs
#
# Package yaml conflicts for:
# pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
# dask-core -> pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
# yaml
#
# Package pyopenssl conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pyopenssl[version='>=0.14']
# urllib3 -> pyopenssl[version='>=0.14']
# pyopenssl
# prometheus_client -> twisted -> pyopenssl[version='>=16.0.0']
#
# Package bleach conflicts for:
# nbconvert -> bleach
# bleach
# jupyter=1.0.0 -> nbconvert -> bleach
# notebook -> nbconvert -> bleach
#
# Package functools32 conflicts for:
# jsonschema -> functools32
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> functools32
# seaborn -> matplotlib[version='>=2.1.2'] -> functools32
# scikit-image -> matplotlib[version='>=2.0.0'] -> functools32
#
# Package pyrsistent conflicts for:
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> pyrsistent[version='>=0.14.0']
# jsonschema -> pyrsistent[version='>=0.14.0']
# pyrsistent
#
# Package chardet conflicts for:
# plotly=3.7.0 -> requests -> chardet[version='>=3.0.2,<3.1.0|>=3.0.2,<4']
# requests -> chardet[version='>=3.0.2,<3.1.0|>=3.0.2,<4']
# chardet
#
# Package lz4-c conflicts for:
# libtiff -> zstd[version='>=1.4'] -> lz4-c[version='>=1.9.2,<1.10.0a0']
# lz4-c
# zstd -> lz4-c[version='>=1.9.2,<1.10.0a0']
#
# Package wincertstore conflicts for:
# wheel -> setuptools -> wincertstore[version='>=0.2']
# jinja2 -> setuptools -> wincertstore[version='>=0.2']
# pywinpty -> setuptools -> wincertstore[version='>=0.2']
# plotly=3.7.0 -> setuptools -> wincertstore[version='>=0.2']
# setuptools -> wincertstore[version='>=0.2']
# pip=19.0 -> setuptools -> wincertstore[version='>=0.2']
# matplotlib=3.0.3 -> setuptools -> wincertstore[version='>=0.2']
# pygments -> setuptools -> wincertstore[version='>=0.2']
# jsonschema -> setuptools -> wincertstore[version='>=0.2']
# bleach -> setuptools -> wincertstore[version='>=0.2']
# networkx -> setuptools -> wincertstore[version='>=0.2']
# ipython -> setuptools[version='>=18.5'] -> wincertstore[version='>=0.2']
# wincertstore
#
# Package prometheus_client conflicts for:
# widgetsnbextension -> notebook[version='>=4.4.1'] -> prometheus_client
# prometheus_client
# notebook -> prometheus_client
# jupyter=1.0.0 -> notebook -> prometheus_client
#
# Package retrying conflicts for:
# plotly=3.7.0 -> retrying[version='>=1.3.3']
# retrying
#
# Package icc_rt conflicts for:
# imageio -> numpy -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# matplotlib=3.0.3 -> numpy -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# mkl_random -> numpy[version='>=1.14,<2.0a0'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# scikit-learn=0.20.3 -> numpy[version='>=1.11.3,<2.0a0'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# numpy-base -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# pywavelets -> numpy[version='>=1.14.6,<2.0a0'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# scikit-image -> numpy[version='>=1.16.6,<2.0a0'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# mkl-service -> numpy[version='>=1.11.3,<2.0a0'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# icc_rt
# torchvision==0.7.0 -> numpy[version='>=1.11'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# mkl_fft -> numpy[version='>=1.14.6,<2.0a0'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# seaborn -> numpy[version='>=1.13.3'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# scipy -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
# numpy=1.16.2 -> icc_rt[version='>=13.1.6|>=2019.0.0']
# pytorch==1.6.0 -> numpy[version='>=1.11'] -> icc_rt[version='>=13.1.6|>=2019.0.0|>=16.0.4']
#
# Package matplotlib-base conflicts for:
# scikit-image -> matplotlib-base[version='>=2.0.0']
# scikit-image -> matplotlib[version='>=2.0.0'] -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0',build='py37h64f37c6_1|py36h64f37c6_1|py36h64f37c6_0|py38h64f37c6_0|py37h64f37c6_0|py38h64f37c6_1']
#
# Package python-dateutil conflicts for:
# scikit-image -> matplotlib-base[version='>=2.0.0'] -> python-dateutil[version='>=2.1']
# qtconsole -> jupyter_client[version='>=4.1'] -> python-dateutil[version='>=2.1']
# python-dateutil
# jupyter_client -> python-dateutil[version='>=2.1']
# nbconvert -> jupyter_client[version='>=4.2'] -> python-dateutil[version='>=2.1']
# nbclient -> jupyter_client[version='>=6.1.5'] -> python-dateutil[version='>=2.1']
# ipykernel -> jupyter_client -> python-dateutil[version='>=2.1']
# seaborn -> matplotlib[version='>=2.1.2'] -> python-dateutil[version='>=2.5.*|>=2.6.1|>=2.7.3']
# notebook -> jupyter_client[version='>=5.3.4'] -> python-dateutil[version='>=2.1']
# matplotlib=3.0.3 -> python-dateutil
# jupyter_console -> jupyter_client -> python-dateutil[version='>=2.1']
#
# Package win_inet_pton conflicts for:
# win_inet_pton
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> win_inet_pton
# pysocks -> win_inet_pton
#
# Package scandir conflicts for:
# importlib_metadata -> pathlib2 -> scandir
# ipython -> pathlib2 -> scandir
# testpath -> pathlib2 -> scandir
# pickleshare -> pathlib2 -> scandir
#
# Package toolz conflicts for:
# cytoolz -> toolz[version='>=0.10.0|>=0.8.0']
# scikit-image -> cytoolz[version='>=0.7.3'] -> toolz[version='>=0.10.0|>=0.8.0|>=0.8.2']
# scikit-image -> toolz[version='>=0.7.3|>=0.7.4']
# toolz
#
# Package pillow conflicts for:
# torchvision==0.7.0 -> pillow[version='>=4.1.1']
# pillow
# imageio -> pillow
# scikit-image -> imageio[version='>=2.3.0'] -> pillow[version='>=6.2.0']
# scikit-image -> pillow[version='>=2.1.0|>=4.3.0']
#
# Package cloudpickle conflicts for:
# scikit-image -> cloudpickle[version='>=0.2.1']
# scikit-image -> dask[version='>=0.5'] -> cloudpickle[version='>=0.2.2']
# cloudpickle
#
# Package pyqt conflicts for:
# seaborn -> matplotlib[version='>=2.1.2'] -> pyqt[version='5.*|5.6.*|5.9.*|>=5.6,<6.0a0|>=5.9.2,<5.10.0a0']
# matplotlib=3.0.3 -> pyqt=5.9
# jupyter=1.0.0 -> qtconsole -> pyqt[version='>=5.9.2,<5.10.0a0']
# scikit-image -> matplotlib[version='>=2.0.0'] -> pyqt[version='5.*|5.6.*|5.9.*|>=5.6,<6.0a0|>=5.9.2,<5.10.0a0']
# qtconsole -> pyqt[version='>=5.9.2,<5.10.0a0']
# pyqt
#
# Package configparser conflicts for:
# jupyter_client -> entrypoints -> configparser
# nbconvert -> entrypoints[version='>=0.2.2'] -> configparser
# jsonschema -> importlib_metadata -> configparser[version='>=3.5']
# importlib_metadata -> configparser[version='>=3.5']
# entrypoints -> configparser
#
# Package win_unicode_console conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> win_unicode_console[version='>=0.5']
# ipywidgets -> ipython[version='>=4.0.0'] -> win_unicode_console[version='>=0.5']
# ipython -> win_unicode_console[version='>=0.5']
# jupyter_console -> ipython -> win_unicode_console[version='>=0.5']
#
# Package kiwisolver conflicts for:
# matplotlib=3.0.3 -> kiwisolver
# kiwisolver
# seaborn -> matplotlib[version='>=2.1.2'] -> kiwisolver
# scikit-image -> matplotlib-base[version='>=2.0.0'] -> kiwisolver[version='>=1.0.1']
#
# Package qtconsole conflicts for:
# qtconsole
# jupyter=1.0.0 -> qtconsole
#
# Package notebook conflicts for:
# jupyter=1.0.0 -> notebook
# widgetsnbextension -> notebook[version='>=4.4.1']
# notebook
# ipywidgets -> widgetsnbextension[version='>=3.5.0,<3.6.0'] -> notebook[version='>=4.4.1']
#
# Package libuv conflicts for:
# torchaudio -> pytorch==1.7.0 -> libuv[version='>=1.40.0,<2.0a0']
# libuv
#
# Package brotlipy conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> brotlipy[version='>=0.6.0']
# brotlipy
# urllib3 -> brotlipy[version='>=0.6.0']
#
# Package parso conflicts for:
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0']
# parso
# ipython -> jedi[version='>=0.10'] -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0']
#
# Package qt conflicts for:
# pyqt -> qt[version='5.6.*|5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0']
# matplotlib=3.0.3 -> pyqt=5.9 -> qt[version='5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0']
# qtconsole -> pyqt -> qt[version='5.6.*|5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0']
# qt
#
# Package jinja2 conflicts for:
# jinja2
# jupyter=1.0.0 -> nbconvert -> jinja2[version='>=2.4']
# notebook -> nbconvert -> jinja2[version='>=2.4']
# notebook -> jinja2
# widgetsnbextension -> notebook[version='>=4.4.1'] -> jinja2
# nbconvert -> jinja2[version='>=2.4']
#
# Package cudatoolkit conflicts for:
# cudatoolkit=11.0
# torchaudio -> pytorch==1.7.0 -> cudatoolkit[version='>=10.1,<10.2|>=11.0,<11.1|>=10.2,<10.3']
#
# Package importlib_metadata conflicts for:
# importlib_metadata
# jsonschema -> importlib_metadata
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> importlib_metadata
#
# Package tk conflicts for:
# scikit-image -> pillow[version='>=4.3.0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# imageio -> pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tk
# torchvision==0.7.0 -> pillow[version='>=4.1.1'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
#
# Package m2w64-gmp conflicts for:
# pywinpty -> m2w64-gcc-libs -> m2w64-gmp
# m2w64-gcc-libs -> m2w64-gmp
# m2w64-gcc-libgfortran -> m2w64-gcc-libs-core -> m2w64-gmp
# m2w64-gcc-libs-core -> m2w64-gmp
# m2w64-gmp
#
# Package imageio conflicts for:
# imageio
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
#
# Package requests conflicts for:
# python=3.7.3 -> pip -> requests
# requests
# plotly=3.7.0 -> requests
#
# Package widgetsnbextension conflicts for:
# ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# jupyter=1.0.0 -> ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# widgetsnbextension
#
# Package webencodings conflicts for:
# webencodings
# bleach -> webencodings
# python=3.7.3 -> pip -> webencodings
# nbconvert -> bleach -> webencodings
#
# Package terminado conflicts for:
# notebook -> terminado[version='>=0.8.1']
# terminado
# widgetsnbextension -> notebook[version='>=4.4.1'] -> terminado[version='>=0.8.1']
# jupyter=1.0.0 -> notebook -> terminado[version='>=0.8.1']
#
# Package packaging conflicts for:
# packaging
# bleach -> packaging
# python=3.7.3 -> pip -> packaging
# nbconvert -> bleach -> packaging
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# pysocks
# requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package typing_extensions conflicts for:
# typing_extensions
# torchaudio -> pytorch==1.7.0 -> typing_extensions
#
# Package zstd conflicts for:
# zstd
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4|>=1.4.4,<1.5.0a0']
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4|>=1.4.4,<1.5.0a0']
#
# Package ipywidgets conflicts for:
# jupyter=1.0.0 -> ipywidgets
# ipywidgets
#
# Package jupyter_console conflicts for:
# jupyter_console
# jupyter=1.0.0 -> jupyter_console
#
# Package xz conflicts for:
# zstd -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# xz
# libtiff -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
#
# Package backports.shutil_which conflicts for:
# pywinpty -> backports.shutil_which
# terminado -> pywinpty -> backports.shutil_which
#
# Package jupyterlab_pygments conflicts for:
# jupyterlab_pygments
# nbconvert -> jupyterlab_pygments
# notebook -> nbconvert -> jupyterlab_pygments
# jupyter=1.0.0 -> nbconvert -> jupyterlab_pygments
#
# Package dask-core conflicts for:
# scikit-image -> dask-core[version='>=0.15|>=0.15.0|>=0.9.0']
# scikit-image -> dask[version='>=0.5'] -> dask-core[version='0.15.2.*|0.15.3.*|0.15.4.*|0.16.0.*|0.16.1.*|0.17.0.*|0.17.1.*|0.17.2.*|0.17.3.*|0.17.4.*|0.17.5.*|0.18.0.*|0.18.1.*|0.18.2.*|0.19.0.*|0.19.1.*|0.19.2.*|0.19.3.*|0.19.4.*|0.20.0.*|0.20.1.*|0.20.2.*|1.0.0.*|1.1.1.*|1.1.2.*|1.1.3.*|1.1.4.*|1.1.5.*|1.2.0.*|1.2.2.*|2.0.0.*|2.1.0.*|2.10.0.*|2.10.1.*|2.11.0.*|2.12.0.*|2.13.0.*|2.14.0.*|2.15.0.*|2.16.0.*|2.17.0.*|2.17.2.*|2.18.1.*|2.19.0.*|2.20.0.*|2.22.0.*|2.23.0.*|2.24.0.*|2.25.0.*|2.26.0.*|2.27.0.*|2.29.0.*|2.30.0.*|2.9.2.*|2.9.1.*|2.9.0.*|2.8.1.*|2.8.0.*|2.7.0.*|2.6.0.*|2.5.2.*|2.5.0.*|2.4.0.*|2.3.0.*|2.2.0.*']
# dask-core
#
# Package pywinpty conflicts for:
# pywinpty
# terminado -> pywinpty
# notebook -> terminado[version='>=0.8.1'] -> pywinpty
#
# Package send2trash conflicts for:
# widgetsnbextension -> notebook[version='>=4.4.1'] -> send2trash
# notebook -> send2trash
# jupyter=1.0.0 -> notebook -> send2trash
# send2trash
#
# Package pandocfilters conflicts for:
# notebook -> nbconvert -> pandocfilters[version='>=1.4.1']
# pandocfilters
# jupyter=1.0.0 -> nbconvert -> pandocfilters[version='>=1.4.1']
# nbconvert -> pandocfilters[version='>=1.4.1']
#
# Package importlib-metadata conflicts for:
# importlib-metadata
# jsonschema -> importlib_metadata -> importlib-metadata[version='>=1.1.3,<1.1.4.0a0|>=1.6.0,<1.6.1.0a0|>=1.6.1,<1.6.2.0a0|>=1.7.0,<1.7.1.0a0|>=2.0.0,<2.0.1.0a0']
# importlib_metadata -> importlib-metadata[version='>=1.1.3,<1.1.4.0a0|>=1.6.0,<1.6.1.0a0|>=1.6.1,<1.6.2.0a0|>=1.7.0,<1.7.1.0a0|>=2.0.0,<2.0.1.0a0']
#
# Package html5lib conflicts for:
# nbconvert -> bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# python=3.7.3 -> pip -> html5lib
#
# Package m2w64-gcc-libs-core conflicts for:
# m2w64-gcc-libgfortran -> m2w64-gcc-libs-core
# m2w64-gcc-libs -> m2w64-gcc-libs-core
# pywinpty -> m2w64-gcc-libs -> m2w64-gcc-libs-core
# m2w64-gcc-libs-core
#
# Package backports.functools_lru_cache conflicts for:
# seaborn -> matplotlib[version='>=2.1.2'] -> backports.functools_lru_cache
# scikit-image -> matplotlib[version='>=2.0.0'] -> backports.functools_lru_cache
#
# Package contextlib2 conflicts for:
# importlib_metadata -> contextlib2
# jsonschema -> importlib_metadata -> contextlib2
#
# Package icu conflicts for:
# qt -> icu[version='>=58.2,<59.0a0']
# icu
# pyqt -> qt=5.9 -> icu[version='>=58.2,<59.0a0']
#
# Package backcall conflicts for:
# ipython -> backcall
# ipywidgets -> ipython[version='>=4.0.0'] -> backcall
# jupyter_console -> ipython -> backcall
# ipykernel -> ipython[version='>=5.0'] -> backcall
# backcall
#
# Package wheel conflicts for:
# pip=19.0 -> wheel
# python=3.7.3 -> pip -> wheel
# wheel
#
# Package pandas conflicts for:
# pandas=0.24.2
# seaborn -> pandas[version='>=0.14.0|>=0.22.0']
# seaborn -> statsmodels[version='>=0.5.0'] -> pandas[version='>=0.14|>=0.21']
# scikit-image -> dask[version='>=0.5'] -> pandas[version='>=0.19.0|>=0.21.0|>=0.23.0']The following specifications were found to be incompatible with your system:
#
#   - feature:/win-64::__cuda==11.1=0
#   - feature:|@/win-64::__cuda==11.1=0
#
# Your installed version is: 11.1

# %% [markdown]
# Since we are using two platforms, we will be assigning a directory to the location of the data for each platform. This will make it easier to access the data, depending the platform we will be using.
#
# The two platforms will be:
# 1. A local installation of  Jupyter Notebook
# 2. A Google Colaboratory Notebook

# %%
windows_path = r'E:\Data_Cloud\GoogleDrive\Dataset\UTKFace'
colab_path = '/content/drive/My Drive/Dataset/UTKFace'
basepath = windows_path

#reassigning the name of the data location
UTKFace_folder = r'E:\Data_Cloud\GoogleDrive\Dataset\Crop\UTKFace'

# %% [markdown]
# ### Exploring the Images in the Data Folder
#
# Next, we will attempt to view the images in the data folder as is. There will be no preprocessing or manipulation at this stage, instead we will be viewing the images.
#
# We will view 5 images from the folder.

# %%
plt.figure(figsize=(30,30))

#looping over the images and selecting random images to view
for i in range(5):
    file = np.random.choice(os.listdir(UTKFace_folder))
    image_path= os.path.join(UTKFace_folder, file)
    image=mpimg.imread(image_path)
    plt.subplot(1,10,i+1)
    plt.imshow(image)

# %% [markdown]
# We will attempt the same procedure, but this time on a single image. We will look closely at just a single random image.

# %%
for i in range(1):
    file = np.random.choice(os.listdir(UTKFace_folder))
    image_path = os.path.join(UTKFace_folder, file)
    image=mpimg.imread(image_path)
    plt.imshow(image)

# %% [markdown]
# ### Creating the Dataset
#
# In this section, we will not attempt to organize and pre-process the data. It is also in this section that we will separate the images between male and female and remove any images with ages below 20 years old and above 60 years old.
#
# The images as been pre-labled and we will be using Regex in retrieving image labels.

# %%
#creating a dataframe selecting gender and ages available
face_df = pd.DataFrame(glob.glob(os.path.join(UTKFace_folder, '*.jpg')), columns=['names'])
face_df['male'] = face_df.names.str.contains(r'\d+_0_[0-4]_\d+.jpg.chip.jpg$') + 0
face_df['age'] = face_df.names.str.extract(r'(\d+)_[0-1]_[0-4]_\d+.jpg.chip.jpg$').astype(int) 

#Limiting Age Group between 20-70
face_df = face_df[face_df['age'] <= 60] 
face_df = face_df[face_df['age'] >= 20]

# %% [markdown]
# We will not view the images after the previous process. The purpose of this step is to verify that we are able to successfully separate the images accordingly.
#
# __Gender:__
#
# 0 - Female
#
# 1 - Male

# %%
for idx, i in enumerate(face_df.sample(6).index):
  plt.figure(figsize=[8,8])
  im_row = face_df.loc[i,:]
  my_image = Image.open(im_row.names).convert('RGB')
  plt.subplot(3,2,idx+1)
  plt.imshow(my_image)
  plt.title(f'Gender {im_row.male} and Age {im_row.age}')

# %% [markdown]
# With the images properly separated, we will first separate the images into two dataframes. One for dataframe for Males and another for Females.

# %%
to_male = face_df[face_df['male'] == 1]
to_female = face_df[face_df['male'] == 0]

# %% [markdown]
# Once again we will verify that the dataframe assigned to the male gender is indeed pulling male images

# %%
for idx, i in enumerate(to_male.sample(3).index):
  plt.figure(figsize=[8,8])
  im_row = face_df.loc[i,:]
  my_image = Image.open(im_row.names).convert('RGB')
  plt.subplot(3,2,idx+1)
  plt.imshow(my_image)
  plt.title(f'Gender {im_row.male} and Age {im_row.age}')

# %% [markdown]
# We will repeat the step, but this time retrieve images of Females. This is once again to verify that the dataset is indeed retreiving the correct images.

# %%
for idx, i in enumerate(to_female.sample(3).index):
  plt.figure(figsize=[8,8])
  im_row = face_df.loc[i,:]
  my_image = Image.open(im_row.names)
  plt.subplot(3,2,idx+1)
  plt.imshow(my_image)
  plt.title(f'Gender {im_row.male} and Age {im_row.age}')

# %% [markdown]
# We will now create global parameters which we can use at several points in this notebook. It will also be easier to remember number assigned.

# %% [markdown]
# ### Resizing the images in the Dataset

# %%
#all_im = glob(os.path.join(basepath, '**/*'))

# %%
# for im in tqdm(all_im):
#     image = Image.open(im)
#     image = image.resize((128,128), Image.BILINEAR)
#     image.save(im)

# %%
#all_im[-1]

# %% [markdown]
# ##Parameters

# %%
#Creating the Parameters

parameters = {'ngf':32,
              'ndf':64,
              'num_epochs':100,
              'decay_epoch': 100,
              'lgG':0.0002,
              'lgD':0.0002,
              'beta1':.5,
              'beta2':.9999,
              'lambdaA':10,
              'lambdaB':10,
              'batch_size':32,
              'pool_size':50, 
              'img_width':256, 
              'img_height':256, 
              'img_depth':3,
              'input_size':128,
              'resize_size':128,
              'crop_size':256,
              'fliplr':True,
              'num_resnet':6,
              'num_workers':2
              }

# %% [markdown]
# ## Creating functions
#
# In the next set, we will create several functions that will be used throughout. The first function will convert our data into Numpy, which we can call at a later point.
#
# We will also set a variable so we can use a GPU for faster processing.

# %%
#Convert to Numpy 
def to_numpy(x):
  return x.data.cpu().numpy()

#use GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Transformer
#
# Since we will be using a __transformer__ at a later stage, we will set a transformer variable and assign it procedures which transforms an image size accordingly. This transformer will also convert the image into a Tensor and Normalize it as well.

# %%
trans = transforms.Compose([
    #transforms.Resize(size=parameters['input_size']),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# %% [markdown]
# Defining a function which will __plot__ the result from training

# %%
def plot_train_result(real_image, gen_image, recon_image, epoch, save=False,  
                      show=True, fig_size=(15, 15)):
   
   fig, axes = plt.subplots(2, 3, figsize=fig_size)
   
   imgs = [to_numpy(real_image[0]), to_numpy(gen_image[0]), 
            to_numpy(recon_image[0]),
            to_numpy(real_image[1]), to_numpy(gen_image[1]), 
            to_numpy(recon_image[1])]
            
   for ax, img in zip(axes.flatten(), imgs):
     
     ax.axis('off')
     img = img.squeeze()
     img = (((img - img.min()) * 255) / (img.max() - img.min())).transpose(1, 2, 0).astype(np.uint8)

     ax.imshow(img, cmap=None, aspect='equal')
    
   plt.subplots_adjust(wspace=0, hspace=0)

   title = 'Epoch {0}'.format(epoch + 1)
   fig.text(0.5, 0.04, title, ha='center')

# %% [markdown]
# Next, we will define an __ImagePool__ function

# %%
class ImagePool():
    def __init__(self, pool_size):
        self.pool_size = pool_size
        if self.pool_size > 0:
            self.num_imgs = 0
            self.images = []

    def query(self, images):
        if self.pool_size == 0:
            return images
        return_images = []
        for image in images.data:
            image = torch.unsqueeze(image, 0)
            if self.num_imgs < self.pool_size:
                self.num_imgs = self.num_imgs + 1
                self.images.append(image)
                return_images.append(image)
            else:
                p = random.uniform(0, 1)
                if p > 0.5:
                    random_id = random.randint(0, self.pool_size-1)
                    tmp = self.images[random_id].clone()
                    self.images[random_id] = image
                    return_images.append(tmp)
                else:
                    return_images.append(image)
        
        return_images = Variable(torch.cat(return_images, 0))
        
        return return_images

# %% [markdown]
# ### Creating the Dataloader
#
# In this section, we begin by creating the __dataloader__ which we will use to retrieve the data in parts.

# %%
class DatasetFromFolder(data.Dataset):
    
    def __init__(self, image_dir, subfolder='train', transform=None, 
                 resize_scale=None, crop_size=None, fliplr=False):
        super(DatasetFromFolder, self).__init__()
        self.input_path = os.path.join(image_dir, subfolder)
        self.image_filenames = [x for x in sorted(os.listdir(self.input_path))]
        self.file_num = len(self.image_filenames)
        self.transform = trans
        
        self.resize_scale = resize_scale
        self.crop_size = crop_size
        self.fliplr = fliplr

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, index):
        # index = total_index % self.file_num
        # Load Images
        img_fn = os.path.join(self.input_path, self.image_filenames[index])
        img = Image.open(img_fn).convert('RGB')

        #preprocessing
        if self.resize_scale:
            img = img.resize((self.resize_scale, self.resize_scale), 
                             Image.BILINEAR)

        if self.crop_size:
            x = random.randint(0, self.resize_scale - self.crop_size + 1)
            y = random.randint(0, self.resize_scale - self.crop_size + 1)
            img = img.crop((x, y, x + self.crop_size, y + self.crop_size))
        
        if self.fliplr:
            if random.random() < 0.5:
                img = img.transpose(Image.FLIP_LEFT_RIGHT)

        if self.transform is not None:
            img = self.transform(img)

        return img

# %% [markdown]
# ### Creating the Convolutional Block
#
# The __convolution__ block will consist of two things.
#
# 1. Initialization
#
# 2. Forward pass.

# %%
class ConvBlock(torch.nn.Module):
    
    #Initialize a dunction
    def __init__(self, input_size, output_size, kernel_size=3, stride=2,
                 padding=1, activation='relu', batch_norm=True):
        super(ConvBlock,self).__init__()
        
        self.conv = torch.nn.Conv2d(input_size, output_size, kernel_size,
                                    stride, padding)
        self.batch_norm = batch_norm
        self.bn = torch.nn.InstanceNorm2d(output_size)
        self.activation = activation
        self.relu = torch.nn.ReLU(True)
        self.lrelu = torch.nn.LeakyReLU(0.2,True)
        self.tanh = torch.nn.Tanh()
    
    #Defining the forward function
    def forward(self,x):
        if self.batch_norm:
            out = self.bn(self.conv(x))
        else:
            out = self.conv(x)
        
        if self.activation == 'relu':
            return self.relu(out)
        elif self.activation == 'lrelu':
            return self.lrelu(out)
        elif self.activation == 'tanh':
            return self.tanh(out)
        elif self.activation == 'no_act':
            return out

# %% [markdown]
# ### De-Convolution Function
#
# In this class we will create, we will need to bring back the convolution from the results previously processed. There will be two functions inside this class.
#
# 1. Initialization
#
# 2. Forward pass

# %%
class DeconvBlock(torch.nn.Module):

    #Initialization Function
    def __init__(self, input_size, output_size, kernel_size=3, stride=2,
                 padding=1, output_padding=1, activation='relu',
                 batch_norm=True):
      
        super(DeconvBlock,self).__init__()

        self.deconv = torch.nn.ConvTranspose2d(input_size, output_size,
                                               kernel_size, stride, padding,
                                               output_padding)
        self.batch_norm = batch_norm
        self.bn = torch.nn.InstanceNorm2d(output_size)
        self.activation = activation
        self.relu = torch.nn.ReLU(True)
    
    #Forward pass
    def forward(self,x):
        if self.batch_norm:
            out = self.bn(self.deconv(x))
        else:
            out = self.deconv(x)
        if self.activation == 'relu':
            return self.relu(out)
        elif self.activation == 'lrelu':
            return self.lrelu(out)
        elif self.activation == 'tanh':
            return self.tanh(out)
        elif self.activation == 'no_act':
            return out

# %% [markdown]
# ### Residual Learning Block
#
# In this secton, we will create a __residual learning__ block or __Resnet__. This class will also contain two functions.
#
# 1. Initialization
#
# 2. Forward pass

# %%
class ResnetBlock(torch.nn.Module):
    def __init__(self,num_filter,kernel_size=3,stride=1,padding=0):
        super(ResnetBlock,self).__init__()

        conv1 = torch.nn.Conv2d(num_filter, num_filter, kernel_size,
                                stride, padding)
        
        conv2 = torch.nn.Conv2d(num_filter, num_filter, kernel_size,
                                stride, padding)
        
        bn = torch.nn.InstanceNorm2d(num_filter)
        relu = torch.nn.ReLU(True)
        pad = torch.nn.ReflectionPad2d(1)
        
        self.resnet_block = torch.nn.Sequential(
            pad,
            conv1,
            bn,
            relu,
            pad,
            conv2,
            bn
            )
    def forward(self,x):
        out = self.resnet_block(x)
        return out

# %% [markdown]
# ##Creating the Generator
#
# We will now create the __Generator__. The Generator will consist of the following:
# 1. Encoder
# 2. Transformer
# 3. Decoder
#
# In addition, we will also be adding __weights__.
#
# After creating the class, we will create the actuall Generator.

# %%
class Generator(torch.nn.Module):
    def __init__(self,input_dim,num_filter,output_dim,num_resnet):
        super(Generator,self).__init__()
        
        #Reflection padding
        self.pad = torch.nn.ReflectionPad2d(3)
        
        #Encoder
        # Input Layer - NN Layer 1
        self.conv1 = ConvBlock(input_dim, num_filter, kernel_size=7, stride=1, 
                               padding=0)
        
        # NN Layer 2
        self.conv2 = ConvBlock(num_filter, num_filter*2)
        
        ## NN Layer 3
        self.conv3 = ConvBlock(num_filter*2, num_filter*4)
        
        #Transformer
        self.resnet_blocks = []
        for i in range(num_resnet):
            self.resnet_blocks.append(ResnetBlock(num_filter*4))
        self.resnet_blocks = torch.nn.Sequential(*self.resnet_blocks)
        
        #Decoder
        self.deconv1 = DeconvBlock(num_filter*4, num_filter*2)
        self.deconv2 = DeconvBlock(num_filter*2, num_filter)
        self.deconv3 = ConvBlock(num_filter, output_dim, kernel_size=7,
                                 stride=1, padding=0, activation='tanh',
                                 batch_norm=False)
    
    #Forward Function
    def forward(self,x):
        
        #Encoder
        enc1 = self.conv1(self.pad(x))
        enc2 = self.conv2(enc1)
        enc3 = self.conv3(enc2)
        
        #Transformer
        res = self.resnet_blocks(enc3)
        
        #Decoder
        dec1 = self.deconv1(res)
        dec2 = self.deconv2(dec1)
        out = self.deconv3(self.pad(dec2))
        return out
    
    #Creating weights inside the Generator
    
    def normal_weight_init(self,mean=0.0,std=0.02):
        for m in self.children():
            if isinstance(m,ConvBlock):
                torch.nn.init.normal_(m.conv.weight,mean,std)
            if isinstance(m,DeconvBlock):
                torch.nn.init.normal_(m.deconv.weight,mean,std)
            if isinstance(m,ResnetBlock):
                torch.nn.init.normal_(m.conv.weight,mean,std)
                torch.nn.init.constant_(m.conv.bias,0)

# %% [markdown]
# ### Creating the Generator and Testing the Neural Network
#
# Since we will be using a Cycle GAN, which requires 2 Neural Networks competing with each other, we will create 2 Generators as its requirement.

# %% [markdown]
# #### Generator A

# %%
Generator_A = Generator(3, parameters['ngf'], 3, 
                        parameters['num_resnet']).cuda()
Generator_A.normal_weight_init(mean=0.0, std=0.02)
Generator_A
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-6b6a56971486> in <module>
#       1 Generator_A = Generator(3, parameters['ngf'], 3,
#       2                         parameters['num_resnet']).cuda()
# ----> 3 Generator_A.normal_weight_init(mean=0.0, std=0.02)
#       4 Generator_A
#
# <ipython-input-23-63a92b14fbe1> in normal_weight_init(self, mean, std)
#      52         for m in self.children():
#      53             if isinstance(m,ConvBlock):
# ---> 54                 torch.nn.init.normal_(m.conv.weight,mean,std)
#      55             if isinstance(m,DeconvBlock):
#      56                 torch.nn.init.normal_(m.deconv.weight,mean,std)
#
# ~\.conda\envs\pytorchenv_gpu\lib\site-packages\torch\nn\init.py in normal_(tensor, mean, std)
#     138         >>> nn.init.normal_(w)
#     139     """
# --> 140     return _no_grad_normal_(tensor, mean, std)
#     141
#     142 def trunc_normal_(tensor, mean=0., std=1., a=-2., b=2.):
#
# ~\.conda\envs\pytorchenv_gpu\lib\site-packages\torch\nn\init.py in _no_grad_normal_(tensor, mean, std)
#      17 def _no_grad_normal_(tensor, mean, std):
#      18     with torch.no_grad():
# ---> 19         return tensor.normal_(mean, std)
#      20
#      21
#
# RuntimeError: CUDA error: no kernel image is available for execution on the device

# %% [markdown]
# #### Generator B

# %%
Generator_B = Generator(3, parameters['ngf'], 3, 
                        parameters['num_resnet']).cuda()
Generator_B.normal_weight_init(mean=0.0, std=0.02)
Generator_B
# Out:
# Generator(
#   (pad): ReflectionPad2d((3, 3, 3, 3))
#   (conv1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv3): ConvBlock(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (resnet_blocks): Sequential(
#     (0): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (1): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (2): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (3): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (4): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (5): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#   )
#   (deconv1): DeconvBlock(
#     (deconv): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv2): DeconvBlock(
#     (deconv): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv3): ConvBlock(
#     (conv): Conv2d(32, 3, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
# )

# %% [markdown]
# ##Creating the Discriminator
#
# The Discriminator will consist of the following
# 1. Initialization
# 2. Forward Pass
# 3. Weights
#
# After creating the class, we will create the actuall Discriminator.

# %%
class Discriminator(torch.nn.Module):
    def __init__(self,input_dim,num_filter,output_dim):
        super(Discriminator,self).__init__()

        #Input - NN Layer 1
        conv1 = ConvBlock(input_dim,num_filter,kernel_size=4,stride=2,padding=1,activation='lrelu',batch_norm=False)
        
        #NN Layer 2
        conv2 = ConvBlock(num_filter,num_filter*2,kernel_size=4,stride=2,padding=1,activation='lrelu')
        
        #NN Layer 3
        conv3 = ConvBlock(num_filter*2,num_filter*4,kernel_size=4,stride=2,padding=1,activation='lrelu')
        
        #NN Layer 4
        conv4 = ConvBlock(num_filter*4,num_filter*8,kernel_size=4,stride=1,padding=1,activation='lrelu')
        
        #Output - NN Layer 5
        conv5 = ConvBlock(num_filter*8,output_dim,kernel_size=4,stride=1,padding=1,activation='no_act',batch_norm=False)
        
        
        self.conv_blocks = torch.nn.Sequential(
            conv1,
            conv2,
            conv3,
            conv4,
            conv5
            )
        
    def forward(self,x):
        out = self.conv_blocks(x)
        return out

    #Creating the weights for the Discriminator
    def normal_weight_init(self, mean=0.0, std=0.02):
        for m in self.children():
            if isinstance(m, ConvBlock):
                torch.nn.init.normal_(m.conv.weight.data, mean, std)

# %% [markdown]
# ### Creating the Discriminator and Testing the Neural Network
#
# Similar with the Generator, which requires 2 Neural Networks. We will create 2 Discriminators that compete with each other.

# %% [markdown]
# #### Discriminator A

# %%
Discriminator_A = Discriminator(3, parameters['ndf'], 1).cuda()
Discriminator_A.normal_weight_init(mean=0.0, std=0.02)
Discriminator_A
# Out:
# Discriminator(
#   (conv_blocks): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (4): ConvBlock(
#       (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(1, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#   )
# )

# %% [markdown]
# #### Discriminator B

# %%
Discriminator_B = Discriminator(3, parameters['ndf'], 1).cuda()
Discriminator_B.normal_weight_init(mean=0.0, std=0.02)
Discriminator_B
# Out:
# Discriminator(
#   (conv_blocks): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (4): ConvBlock(
#       (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(1, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#   )
# )

# %% [markdown]
# ## Training Block / DataLoaders
#
# In this block, we will create the actual training block we will be using to train our model.

# %%
train_data_A = DatasetFromFolder(basepath, subfolder='trainA_Male', transform=trans,
                                resize_scale=parameters['resize_size'], 
                                #crop_size=parameters['crop_size'], 
                                #fliplr=parameters['fliplr']
                                 )

train_data_loader_A = torch.utils.data.DataLoader(dataset=train_data_A, 
                                                  batch_size=parameters['batch_size'], 
                                                  num_workers=parameters['num_workers'],
                                                  pin_memory=True,
                                                  shuffle=True)

train_data_B = DatasetFromFolder(basepath, subfolder='trainB_Female', transform=trans,
                                 resize_scale=parameters['resize_size'], 
                                 #crop_size=parameters['crop_size'], 
                                 #fliplr=True
                                 )

train_data_loader_B = torch.utils.data.DataLoader(dataset=train_data_B, 
                                                  batch_size=parameters['batch_size'], 
                                                  num_workers=parameters['num_workers'],
                                                  pin_memory=True,
                                                  shuffle=True)

#Load test data
test_data_A = DatasetFromFolder(basepath, subfolder='testA_Male', transform=trans)

test_data_loader_A = torch.utils.data.DataLoader(dataset=test_data_A, 
                                                 batch_size=parameters['batch_size'], 
                                                 shuffle=False)

test_data_B = DatasetFromFolder(basepath, subfolder='trainB_Female', transform=trans)

test_data_loader_B = torch.utils.data.DataLoader(dataset=test_data_B, 
                                                 batch_size=parameters['batch_size'], 
                                                 shuffle=False)

# %%
print(train_data_A.resize_scale)
# Out:
# 128

# %% [markdown]
# ## Retreiving Items
#
# In this block / section we will be retreiving an item for both the real data generated twice. We will also show this data not as an image, but as a Tensor array. We will do this to verify that there are some changes made compared to it's original state.

# %% [markdown]
# ### Test Real Data A

# %%
test_real_A_data = train_data_A.__getitem__(11).unsqueeze(0)
test_real_A_data
# Out:
# tensor([[[[-0.7490, -0.8118, -0.8667,  ..., -0.6863, -0.6314, -0.5529],
#           [-0.7490, -0.8118, -0.8667,  ..., -0.7333, -0.6549, -0.5529],
#           [-0.7333, -0.7882, -0.8353,  ..., -0.7412, -0.6627, -0.5608],
#           ...,
#           [-0.6941, -0.7020, -0.7176,  ..., -0.6078, -0.6392, -0.6314],
#           [-0.6863, -0.6941, -0.7176,  ..., -0.6078, -0.6471, -0.6549],
#           [-0.6863, -0.6941, -0.7176,  ..., -0.6235, -0.6471, -0.6549]],
#
#          [[-0.7490, -0.8118, -0.8667,  ..., -0.7490, -0.7098, -0.6314],
#           [-0.7490, -0.8118, -0.8667,  ..., -0.7961, -0.7333, -0.6314],
#           [-0.7333, -0.7882, -0.8353,  ..., -0.8039, -0.7255, -0.6235],
#           ...,
#           [-0.7569, -0.7647, -0.7569,  ..., -0.6078, -0.6078, -0.5922],
#           [-0.7490, -0.7569, -0.7569,  ..., -0.6078, -0.6000, -0.5922],
#           [-0.7490, -0.7569, -0.7569,  ..., -0.6078, -0.6078, -0.5922]],
#
#          [[-0.8431, -0.8902, -0.9294,  ..., -0.7647, -0.7176, -0.6471],
#           [-0.8431, -0.8902, -0.9294,  ..., -0.8118, -0.7412, -0.6392],
#           [-0.8275, -0.8667, -0.8980,  ..., -0.8196, -0.7412, -0.6392],
#           ...,
#           [-0.7804, -0.7804, -0.7804,  ..., -0.6235, -0.6000, -0.5686],
#           [-0.7725, -0.7725, -0.7804,  ..., -0.6078, -0.6000, -0.5765],
#           [-0.7725, -0.7725, -0.7804,  ..., -0.6157, -0.5843, -0.5686]]]])

# %% [markdown]
# ### Test Real Data B

# %%
test_real_B_data = train_data_B.__getitem__(11).unsqueeze(0)
test_real_B_data
# Out:
# tensor([[[[-0.8431, -0.8667, -0.8980,  ...,  0.0039,  0.1843,  0.2706],
#           [-0.8588, -0.8824, -0.9059,  ..., -0.0588,  0.1765,  0.3098],
#           [-0.8667, -0.8902, -0.9059,  ..., -0.1294,  0.1294,  0.2941],
#           ...,
#           [-0.8902, -0.8745, -0.8431,  ..., -0.9137, -0.9059, -0.8980],
#           [-0.8824, -0.8745, -0.8510,  ..., -0.9059, -0.8980, -0.8902],
#           [-0.8745, -0.8824, -0.8588,  ..., -0.9059, -0.8902, -0.8824]],
#
#          [[-0.8353, -0.8510, -0.8667,  ..., -0.1843, -0.0118,  0.0510],
#           [-0.8588, -0.8667, -0.8745,  ..., -0.2471, -0.0196,  0.0980],
#           [-0.8667, -0.8745, -0.8824,  ..., -0.3176, -0.0745,  0.0745],
#           ...,
#           [-0.9137, -0.8980, -0.8902,  ..., -0.9216, -0.9137, -0.9059],
#           [-0.9059, -0.8980, -0.8980,  ..., -0.9137, -0.9059, -0.8980],
#           [-0.8980, -0.9059, -0.9059,  ..., -0.9137, -0.8980, -0.8902]],
#
#          [[-0.9451, -0.9529, -0.9529,  ..., -0.4667, -0.3412, -0.3098],
#           [-0.9529, -0.9529, -0.9451,  ..., -0.5294, -0.3412, -0.2627],
#           [-0.9608, -0.9608, -0.9451,  ..., -0.5843, -0.3882, -0.2784],
#           ...,
#           [-0.9529, -0.9529, -0.9451,  ..., -0.9529, -0.9451, -0.9373],
#           [-0.9451, -0.9529, -0.9451,  ..., -0.9451, -0.9373, -0.9294],
#           [-0.9373, -0.9529, -0.9529,  ..., -0.9451, -0.9294, -0.9216]]]])

# %% [markdown]
# ## Creating the Optimizer

# %%
Generator_optimizer = torch.optim.Adam(itertools.chain(Generator_A.parameters(),
                                                       Generator_B.parameters()),
                                                       betas=(parameters['beta1'], parameters['beta2']),
                                                       lr=parameters['lgG'])

Discriminator_A_optimizer = torch.optim.Adam(itertools.chain(Discriminator_A.parameters(),
                                                           Discriminator_B.parameters()),
                                                           betas=(parameters['beta1'], parameters['beta2']),
                                                           lr=parameters['lgD'])

Discriminator_B_optimizer = torch.optim.Adam(itertools.chain(Discriminator_A.parameters(),
                                                           Discriminator_B.parameters()),
                                                           betas=(parameters['beta1'], parameters['beta2']),
                                                           lr=parameters['lgD'])

# %% [markdown]
# ## Defining Losses

# %%
MSE_Loss = torch.nn.MSELoss().cuda()
L1_Loss = torch.nn.L1Loss().cuda()

# %%
Discriminator_A_avg_losses = []
Discriminator_B_avg_losses = []
Generator_A_avg_losses = []
Generator_B_avg_losses = []

cycle_A_avg_losses = []
cycle_B_avg_losses = []

# %% [markdown]
# ## Training the model and retreiving Images

# %% [markdown]
# Using the image pool created earliler, we will create a pool of variables which we will be using for training at the next cell block.

# %%
num_pool = 50
fake_A_Pool = ImagePool(num_pool)
fake_B_Pool = ImagePool(num_pool)

step = 0

# %% [markdown]
# We will now run the Training sequence in the block.

# %%
scaler = torch.cuda.amp.GradScaler(enabled=True)
best_gen = np.inf

for epoch in range(parameters['num_epochs']):
    Discriminator_A_losses = []
    Discriminator_B_losses = []
    Generator_A_losses = []
    Generator_B_losses = []
    cycle_A_losses = []
    cycle_B_losses = []
    
    # Learing rate decay 
    if(epoch + 1) > parameters['decay_epoch']:
        Discriminatoroptimizer.param_groups[0]['lr'] -= parameters['lgD'] / (parameters['num_epochs'] - parameters['decay_epoch'])
        Discriminator_B_optimizer.param_groups[0]['lr'] -= parameters['lgD'] / (parameters['num_epochs'] - parameters['decay_epoch'])
        G_optimizer.param_groups[0]['lr'] -= parameters['lrG'] / (parameters['num_epochs'] - parameters['decay_epoch'])
        
    
    # training 
    for i, (real_A, real_B) in tqdm(enumerate(zip(train_data_loader_A, train_data_loader_B)), total=len(train_data_loader_A)):
        
        # input image data
        real_A = real_A.to(device)
        real_B = real_B.to(device)
        
        # Train The Generator

        # A --> B
        fake_B = Generator_A(real_A)
        Discriminator_B_fake_decision = Discriminator_B(fake_B)
        Generator_A_loss = MSE_Loss(Discriminator_B_fake_decision, Variable(torch.ones(Discriminator_B_fake_decision.size()).cuda()))
        
        # Forward Cycle Loss
        recon_A = Generator_B(fake_B)
        cycle_A_loss = L1_Loss(recon_A, real_A) * parameters['lambdaA']
        
        # B --> A
        fake_A = Generator_B(real_B)
        Discriminator_A_fake_decision = Discriminator_A(fake_A)
        Generator_B_loss = MSE_Loss(Discriminator_A_fake_decision, Variable(torch.ones(Discriminator_A_fake_decision.size()).cuda()))
        
        # Backward Cycle Loss
        recon_B = Generator_A(fake_A)
        cycle_B_loss = L1_Loss(recon_B, real_B) * parameters['lambdaB']
        
        # Back Propagation
        Generator_loss = Generator_A_loss + Generator_B_loss + cycle_A_loss + cycle_B_loss
        Generator_optimizer.zero_grad()
        Generator_loss.backward()
        Generator_optimizer.step()
        
        
        # Train Discriminator_A 
        Discriminator_A_real_decision = Discriminator_A(real_A)
        Discriminator_A_real_loss = MSE_Loss(Discriminator_A_real_decision, Variable(torch.ones(Discriminator_A_real_decision.size()).cuda()))
        
        fake_A = fake_A_Pool.query(fake_A)
        
        Discriminator_A_fake_decision = Discriminator_A(fake_A)
        Discriminator_A_fake_loss = MSE_Loss(Discriminator_A_fake_decision, Variable(torch.zeros(Discriminator_A_fake_decision.size()).cuda()))
        
        # Back propagation
        Discriminator_A_loss = (Discriminator_A_real_loss + Discriminator_A_fake_loss) * 0.5
        Discriminator_A_optimizer.zero_grad()
        Discriminator_A_loss.backward()
        Discriminator_A_optimizer.step()
        
        # Train Discriminator_B 
        Discriminator_B_real_decision = Discriminator_B(real_B)
        # print('real_A, ',real_A.shape)
        # print('real_B, ',real_B.shape)
        # print('dis_A, ',Discriminator_A_real_decision.shape)
        # print('dis_B, ',Discriminator_B_real_decision.shape)
        Discriminator_B_real_loss = MSE_Loss(Discriminator_B_real_decision, Variable(torch.ones(Discriminator_B_fake_decision.size()).cuda()))
        #Discriminator_B_real_loss = MSE_Loss(Discriminator_B_real_decision, Variable(torch.ones(Discriminator_B_real_decision.size()).cuda()))
        
       
        fake_B = fake_B_Pool.query(fake_B)
        
        Discriminator_B_fake_decision = Discriminator_B(fake_B)
        Discriminator_B_fake_loss = MSE_Loss(Discriminator_B_fake_decision, Variable(torch.zeros(Discriminator_B_fake_decision.size()).cuda()))
        
        # Back Propagation
        Discriminator_B_loss = (Discriminator_B_real_loss + Discriminator_B_fake_loss) * 0.5
        Discriminator_B_optimizer.zero_grad()
        Discriminator_B_loss.backward()
        Discriminator_B_optimizer.step()
        
        #  Print 


        # loss values
        Discriminator_A_losses.append(Discriminator_A_loss.item())
        Discriminator_B_losses.append(Discriminator_B_loss.item())
        Generator_A_losses.append(Generator_A_loss.item())
        Generator_B_losses.append(Generator_B_loss.item())
        cycle_A_losses.append(cycle_A_loss.item())
        cycle_B_losses.append(cycle_B_loss.item())

        if i%100 == 0:
            print('Epoch [%d/%d], Step [%d/%d], Discriminator_A_losses: %.4f, Discriminator_B_loss: %.4f, Generator_A_loss: %.4f, Generator_B_loss: %.4f'
                  % (epoch+1, parameters['num_epochs'], i+1, len(train_data_loader_A), Discriminator_A_loss.item(), Discriminator_B_loss.item(), Generator_A_loss.item(), Generator_B_loss.item()))
            
        step += 1
        
    Discriminator_A_avg_loss = torch.mean(torch.FloatTensor(Discriminator_A_losses))
    Discriminator_B_avg_loss = torch.mean(torch.FloatTensor(Discriminator_B_losses))
    Generator_A_avg_loss = torch.mean(torch.FloatTensor(Generator_A_losses))
    Generator_B_avg_loss = torch.mean(torch.FloatTensor(Generator_B_losses))
    cycle_A_avg_loss = torch.mean(torch.FloatTensor(cycle_A_losses))
    cycle_B_avg_loss = torch.mean(torch.FloatTensor(cycle_B_losses))

    # Average Loss Values
    Discriminator_A_avg_losses.append(Discriminator_A_avg_loss.item())
    Discriminator_B_avg_losses.append(Discriminator_B_avg_loss.item())
    Generator_A_avg_losses.append(Generator_A_avg_loss.item())
    Generator_B_avg_losses.append(Generator_B_avg_loss.item())
    cycle_A_avg_losses.append(cycle_A_avg_loss.item())
    cycle_B_avg_losses.append(cycle_B_avg_loss.item())
    
    # Test Image Results
    test_real_A = test_real_A_data.cuda()
    test_fake_B = Generator_A(test_real_A)
    test_recon_A = Generator_B(test_fake_B)

    test_real_B = test_real_B_data.cuda()
    test_fake_A = Generator_B(test_real_B)
    test_recon_B = Generator_A(test_fake_A)

    plot_train_result([test_real_A, test_real_B], [test_fake_B, test_fake_A], [test_recon_A, test_recon_B],
                            epoch, save=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
 ""

# %% [markdown]
# ## Retreiving the Loss results

# %%
all_losses = pd.DataFrame()
all_losses['Discriminator_A_avg_losses'] = Discriminator_A_avg_losses
all_losses['Discriminator_B_avg_losses'] = Discriminator_B_avg_losses
all_losses['Generator_A_avg_losses'] = Generator_A_avg_losses
all_losses['Generator_B_avg_losses'] = Generator_B_avg_losses
all_losses['cycle_A_avg_losses'] = cycle_A_avg_losses
all_losses['cycle_B_avg_losses'] = cycle_B_avg_losses

print(all_losses)
# Out:
#     Discriminator_A_avg_losses  ...  cycle_B_avg_losses
# 0                     0.197438  ...            2.595257
# 1                     0.151447  ...            2.161373
# 2                     0.148603  ...            1.863805
# 3                     0.137356  ...            1.756926
# 4                     0.158026  ...            1.672991
# ..                         ...  ...                 ...
# 95                    0.240221  ...            0.806677
# 96                    0.238966  ...            0.807786
# 97                    0.240525  ...            0.801443
# 98                    0.236204  ...            0.801622
# 99                    0.217244  ...            2.778415
#
# [100 rows x 6 columns]

# %%
#save to csv
all_losses.to_csv('E:\Data_Cloud\GoogleDrive\Thinkful\CapstoneIV\all_losses.csv', index=False)

# %% [markdown]
# ## Saving the Model

# %%
directory_ = r'E:\Data_Cloud\GoogleDrive\Thinkful\CapstoneIV'

torch.save(Generator_A.state_dict(), directory_)
torch.save(Generator_B.state_dict(), directory_)
torch.save(Discrimninator_A.state_dict(),  directory_)
torch.save(Discriminator_B.state_dict(),  directory_)

torch.save(Generator_optimizer.state_dict(), directory_)
torch.save(Discrimninator_A_optimizer.state_dict(),  directory_)
torch.save(Discriminator_B_optimizer.state_dict(),  directory_)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-69-e55be7e9db27> in <module>()
#       1 directory_ = '/content/drive/My Drive/Thinkful/CapstoneIV/'
#       2
# ----> 3 torch.save(Generator_A.state_dict(), directory_)
#       4 #torch.save(Generator_B.state_dict(),  '/content/drive/My Drive/Thinkful/CapstoneIV')
#       5 # torch.save(Discrimninator_A.state_dict(),  '/content/drive/My Drive/Thinkful/CapstoneIV')
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     367     _check_dill_version(pickle_module)
#     368
# --> 369     with _open_file_like(f, 'wb') as opened_file:
#     370         if _use_new_zipfile_serialization:
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/My Drive/Thinkful/CapstoneIV/'

# %%
torch.save( )
