# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Introduction
#
# In this project, we will attempt to greate a Cycle Generative Adversarial Network (cycleGAN) in order to manipulate facial images. We will attempt to change the gender for a set of images.

# %% [markdown]
# Our first step is to load the neccessary libraries we will be using for the entire process.

# %%
#Loading the neccessary libraries
# %matplotlib inline

import os, random, cv2, glob, itertools, shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable

import torchvision
from torchvision import datasets, transforms, utils
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Since we are using two platforms, we will be assigning a directory to the location of the data for each platform. This will make it easier to access the data, depending the platform we will be using.
#
# The two platforms will be:
# 1. A local installation of  Jupyter Notebook
# 2. A Google Colaboratory Notebook

# %%
windows_path = '''E:\Data_Cloud\GoogleDrive\Dataset'''
colab_path = '/content/drive/My Drive/Dataset/UTKFace_Resize'
basepath = colab_path

# %% [markdown]
# ### Exploring the Images in the Data Folder
#
# Next, we will attempt to view the images in the data folder as is. There will be no preprocessing or manipulation at this stage, instead we will be viewing the images.
#
# We will view 5 images from the folder.

# %%
plt.figure(figsize=(30,30))

#reassigning the name of the data location
UTKFace_folder = '/content/drive/My Drive/Dataset/Crop/UTKFace'

#looping over the images and selecting random images to view
for i in range(5):
    file = np.random.choice(os.listdir(UTKFace_folder))
    image_path= os.path.join(UTKFace_folder, file)
    image=mpimg.imread(image_path)
    plt.subplot(1,10,i+1)
    plt.imshow(image)

# %% [markdown]
# We will attempt the same procedure, but this time on a single image. We will look closely at just a single random image.

# %%
for i in range(1):
    file = np.random.choice(os.listdir(UTKFace_folder))
    image_path = os.path.join(UTKFace_folder, file)
    image=mpimg.imread(image_path)
    plt.imshow(image)

# %% [markdown]
# ### Creating the Dataset
#
# In this section, we will not attempt to organize and pre-process the data. It is also in this section that we will separate the images between male and female and remove any images with ages below 20 years old and above 60 years old.
#
# The images as been pre-labled and we will be using Regex in retrieving image labels.

# %%
#creating a dataframe selecting gender and ages available
face_df = pd.DataFrame(glob.glob(os.path.join(UTKFace_folder, '*.jpg')), columns=['names'])
face_df['male'] = face_df.names.str.contains(r'\d+_0_[0-4]_\d+.jpg.chip.jpg$') + 0
face_df['age'] = face_df.names.str.extract(r'(\d+)_[0-1]_[0-4]_\d+.jpg.chip.jpg$').astype(int) 

#Limiting Age Group between 20-70
face_df = face_df[face_df['age'] <= 60] 
face_df = face_df[face_df['age'] >= 20]

# %% [markdown]
# We will not view the images after the previous process. The purpose of this step is to verify that we are able to successfully separate the images accordingly.
#
# __Gender:__
#
# 0 - Female
#
# 1 - Male

# %%
for idx, i in enumerate(face_df.sample(6).index):
  plt.figure(figsize=[8,8])
  im_row = face_df.loc[i,:]
  my_image = Image.open(im_row.names).convert('RGB')
  plt.subplot(3,2,idx+1)
  plt.imshow(my_image)
  plt.title(f'Gender {im_row.male} and Age {im_row.age}')

# %% [markdown]
# With the images properly separated, we will first separate the images into two dataframes. One for dataframe for Males and another for Females.

# %%
to_male = face_df[face_df['male'] == 1]
to_female = face_df[face_df['male'] == 0]

# %% [markdown]
# Once again we will verify that the dataframe assigned to the male gender is indeed pulling male images

# %%
for idx, i in enumerate(to_male.sample(3).index):
  plt.figure(figsize=[8,8])
  im_row = face_df.loc[i,:]
  my_image = Image.open(im_row.names).convert('RGB')
  plt.subplot(3,2,idx+1)
  plt.imshow(my_image)
  plt.title(f'Gender {im_row.male} and Age {im_row.age}')

# %% [markdown]
# We will repeat the step, but this time retrieve images of Females. This is once again to verify that the dataset is indeed retreiving the correct images.

# %%
for idx, i in enumerate(to_female.sample(3).index):
  plt.figure(figsize=[8,8])
  im_row = face_df.loc[i,:]
  my_image = Image.open(im_row.names)
  plt.subplot(3,2,idx+1)
  plt.imshow(my_image)
  plt.title(f'Gender {im_row.male} and Age {im_row.age}')

# %% [markdown]
# We will now create global parameters which we can use at several points in this notebook. It will also be easier to remember number assigned.

# %% [markdown]
# ##Parameters

# %%
#Creating the Parameters

parameters = {'ngf':32,
              'ndf':64,
              'num_epochs':100,
              'decay_epoch': 100,
              'lgG':0.0002,
              'lgD':0.0002,
              'beta1':.5,
              'beta2':.9999,
              'lambdaA':10,
              'lambdaB':10,
              'batch_size':20,
              'pool_size':50, 
              'img_width':256, 
              'img_height':256, 
              'img_depth':3,
              'input_size':128,
              'resize_size':286,
              'crop_size':256,
              'fliplr':True,
              'num_resnet':6,
              'num_workers':4
              }

# %% [markdown]
# ## Creating functions
#
# In the next set, we will create several functions that will be used throughout. The first function will convert our data into Numpy, which we can call at a later point.
#
# We will also set a variable so we can use a GPU for faster processing.

# %%
#Convert to Numpy 
def to_numpy(x):
  return x.data.cpu().numpy()

#use GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Transformer
#
# Since we will be using a __transformer__ at a later stage, we will set a transformer variable and assign it procedures which transforms an image size accordingly. This transformer will also convert the image into a Tensor and Normalize it as well.

# %%
trans = transforms.Compose([
    transforms.Resize(size=parameters['input_size']),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# %% [markdown]
# Defining a function which will __plot__ the result from training

# %%
def plot_train_result(real_image, gen_image, recon_image, epoch, save=False,  
                      show=True, fig_size=(15, 15)):
   
   fig, axes = plt.subplots(2, 3, figsize=fig_size)
   
   imgs = [to_numpy(real_image[0]), to_numpy(gen_image[0]), 
            to_numpy(recon_image[0]),
            to_numpy(real_image[1]), to_numpy(gen_image[1]), 
            to_numpy(recon_image[1])]
            
   for ax, img in zip(axes.flatten(), imgs):
     
     ax.axis('off')
     img = img.squeeze()
     img = (((img - img.min()) * 255) / (img.max() - img.min())).transpose(1, 2, 0).astype(np.uint8)

     ax.imshow(img, cmap=None, aspect='equal')
    
   plt.subplots_adjust(wspace=0, hspace=0)

   title = 'Epoch {0}'.format(epoch + 1)
   fig.text(0.5, 0.04, title, ha='center')

# %% [markdown]
# Next, we will define an __ImagePool__ function

# %%
class ImagePool():
    def __init__(self, pool_size):
        self.pool_size = pool_size
        if self.pool_size > 0:
            self.num_imgs = 0
            self.images = []

    def query(self, images):
        if self.pool_size == 0:
            return images
        return_images = []
        for image in images.data:
            image = torch.unsqueeze(image, 0)
            if self.num_imgs < self.pool_size:
                self.num_imgs = self.num_imgs + 1
                self.images.append(image)
                return_images.append(image)
            else:
                p = random.uniform(0, 1)
                if p > 0.5:
                    random_id = random.randint(0, self.pool_size-1)
                    tmp = self.images[random_id].clone()
                    self.images[random_id] = image
                    return_images.append(tmp)
                else:
                    return_images.append(image)
        
        return_images = Variable(torch.cat(return_images, 0))
        
        return return_images

# %% [markdown]
# ### Creating the Dataloader
#
# In this section, we begin by creating the __dataloader__ which we will use to retrieve the data in parts.

# %%
class DatasetFromFolder(data.Dataset):
    
    def __init__(self, image_dir, subfolder='train', transform=None, 
                 resize_scale=None, crop_size=None, fliplr=False):
        super(DatasetFromFolder, self).__init__()
        self.input_path = os.path.join(image_dir, subfolder)
        self.image_filenames = [x for x in sorted(os.listdir(self.input_path))]
        self.transform = trans
        
        self.resize_scale = resize_scale
        self.crop_size = crop_size
        self.fliplr = fliplr

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, index):

        # Load Images
        img_fn = os.path.join(self.input_path, self.image_filenames[index])
        img = Image.open(img_fn).convert('RGB')

        # preprocessing
        if self.resize_scale:
            img = img.resize((self.resize_scale, self.resize_scale), 
                             Image.BILINEAR)

        if self.crop_size:
            x = random.randint(0, self.resize_scale - self.crop_size + 1)
            y = random.randint(0, self.resize_scale - self.crop_size + 1)
            img = img.crop((x, y, x + self.crop_size, y + self.crop_size))
        
        if self.fliplr:
            if random.random() < 0.5:
                img = img.transpose(Image.FLIP_LEFT_RIGHT)

        if self.transform is not None:
            img = self.transform(img)

        return img

# %% [markdown]
# ### Creating the Convolutional Block
#
# The __convolution__ block will consist of two things.
#
# 1. Initialization
#
# 2. Forward pass.

# %%
class ConvBlock(torch.nn.Module):
    
    #Initialize a dunction
    def __init__(self, input_size, output_size, kernel_size=3, stride=2,
                 padding=1, activation='relu', batch_norm=True):
        super(ConvBlock,self).__init__()
        
        self.conv = torch.nn.Conv2d(input_size, output_size, kernel_size,
                                    stride, padding)
        self.batch_norm = batch_norm
        self.bn = torch.nn.InstanceNorm2d(output_size)
        self.activation = activation
        self.relu = torch.nn.ReLU(True)
        self.lrelu = torch.nn.LeakyReLU(0.2,True)
        self.tanh = torch.nn.Tanh()
    
    #Defining the forward function
    def forward(self,x):
        if self.batch_norm:
            out = self.bn(self.conv(x))
        else:
            out = self.conv(x)
        
        if self.activation == 'relu':
            return self.relu(out)
        elif self.activation == 'lrelu':
            return self.lrelu(out)
        elif self.activation == 'tanh':
            return self.tanh(out)
        elif self.activation == 'no_act':
            return out

# %% [markdown]
# ### De-Convolution Function
#
# In this class we will create, we will need to bring back the convolution from the results previously processed. There will be two functions inside this class.
#
# 1. Initialization
#
# 2. Forward pass

# %%
class DeconvBlock(torch.nn.Module):

    #Initialization Function
    def __init__(self, input_size, output_size, kernel_size=3, stride=2,
                 padding=1, output_padding=1, activation='relu',
                 batch_norm=True):
      
        super(DeconvBlock,self).__init__()

        self.deconv = torch.nn.ConvTranspose2d(input_size, output_size,
                                               kernel_size, stride, padding,
                                               output_padding)
        self.batch_norm = batch_norm
        self.bn = torch.nn.InstanceNorm2d(output_size)
        self.activation = activation
        self.relu = torch.nn.ReLU(True)
    
    #Forward pass
    def forward(self,x):
        if self.batch_norm:
            out = self.bn(self.deconv(x))
        else:
            out = self.deconv(x)
        if self.activation == 'relu':
            return self.relu(out)
        elif self.activation == 'lrelu':
            return self.lrelu(out)
        elif self.activation == 'tanh':
            return self.tanh(out)
        elif self.activation == 'no_act':
            return out

# %% [markdown]
# ### Residual Learning Block
#
# In this secton, we will create a __residual learning__ block or __Resnet__. This class will also contain two functions.
#
# 1. Initialization
#
# 2. Forward pass

# %%
class ResnetBlock(torch.nn.Module):
    def __init__(self,num_filter,kernel_size=3,stride=1,padding=0):
        super(ResnetBlock,self).__init__()

        conv1 = torch.nn.Conv2d(num_filter, num_filter, kernel_size,
                                stride, padding)
        
        conv2 = torch.nn.Conv2d(num_filter, num_filter, kernel_size,
                                stride, padding)
        
        bn = torch.nn.InstanceNorm2d(num_filter)
        relu = torch.nn.ReLU(True)
        pad = torch.nn.ReflectionPad2d(1)
        
        self.resnet_block = torch.nn.Sequential(
            pad,
            conv1,
            bn,
            relu,
            pad,
            conv2,
            bn
            )
    def forward(self,x):
        out = self.resnet_block(x)
        return out

# %% [markdown]
# ##Creating the Generator
#
# We will now create the __Generator__. The Generator will consist of the following:
# 1. Encoder
# 2. Transformer
# 3. Decoder
#
# In addition, we will also be adding __weights__.
#
# After creating the class, we will create the actuall Generator.

# %%
class Generator(torch.nn.Module):
    def __init__(self,input_dim,num_filter,output_dim,num_resnet):
        super(Generator,self).__init__()
        
        #Reflection padding
        self.pad = torch.nn.ReflectionPad2d(3)
        
        #Encoder
        # Input Layer - NN Layer 1
        self.conv1 = ConvBlock(input_dim, num_filter, kernel_size=7, stride=1, 
                               padding=0)
        
        # NN Layer 2
        self.conv2 = ConvBlock(num_filter, num_filter*2)
        
        ## NN Layer 3
        self.conv3 = ConvBlock(num_filter*2, num_filter*4)
        
        #Transformer
        self.resnet_blocks = []
        for i in range(num_resnet):
            self.resnet_blocks.append(ResnetBlock(num_filter*4))
        self.resnet_blocks = torch.nn.Sequential(*self.resnet_blocks)
        
        #Decoder
        self.deconv1 = DeconvBlock(num_filter*4, num_filter*2)
        self.deconv2 = DeconvBlock(num_filter*2, num_filter)
        self.deconv3 = ConvBlock(num_filter, output_dim, kernel_size=7,
                                 stride=1, padding=0, activation='tanh',
                                 batch_norm=False)
    
    #Forward Function
    def forward(self,x):
        
        #Encoder
        enc1 = self.conv1(self.pad(x))
        enc2 = self.conv2(enc1)
        enc3 = self.conv3(enc2)
        
        #Transformer
        res = self.resnet_blocks(enc3)
        
        #Decoder
        dec1 = self.deconv1(res)
        dec2 = self.deconv2(dec1)
        out = self.deconv3(self.pad(dec2))
        return out
    
    #Creating weights inside the Generator
    
    # def weights(m, mean=0.0, std = 0.02):
    #   for m in self.children():
    #     if isinstance(m, nn.Conv2d):
    #       nn.init.normal_(m.weight, 0.0, 0.02)
    #     elif isinstance(m, nn.BatchNorm2d):
    #       nn.init.normal_(m.weight, 0.0, 0.02)
    #       nn.init.constant_(m.bias, 0)
    
    def normal_weight_init(self,mean=0.0,std=0.02):
        for m in self.children():
            if isinstance(m,ConvBlock):
                torch.nn.init.normal_(m.conv.weight,mean,std)
            if isinstance(m,DeconvBlock):
                torch.nn.init.normal_(m.deconv.weight,mean,std)
            if isinstance(m,ResnetBlock):
                torch.nn.init.normal_(m.conv.weight,mean,std)
                torch.nn.init.constant_(m.conv.bias,0)

# %% [markdown]
# ### Creating the Generator and Testing the Neural Network
#
# Since we will be using a Cycle GAN, which requires 2 Neural Networks competing with each other, we will create 2 Generators as its requirement.

# %% [markdown]
# #### Generator A

# %%
Generator_A = Generator(3, parameters['ngf'], 3, 
                        parameters['num_resnet']).cuda()
Generator_A.normal_weight_init(mean=0.0, std=0.02)
Generator_A
# Out:
# Generator(
#   (pad): ReflectionPad2d((3, 3, 3, 3))
#   (conv1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv3): ConvBlock(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (resnet_blocks): Sequential(
#     (0): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (1): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (2): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (3): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (4): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (5): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#   )
#   (deconv1): DeconvBlock(
#     (deconv): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv2): DeconvBlock(
#     (deconv): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv3): ConvBlock(
#     (conv): Conv2d(32, 3, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
# )

# %% [markdown]
# #### Generator B

# %%
Generator_B = Generator(3, parameters['ngf'], 3, 
                        parameters['num_resnet']).cuda()
Generator_B.normal_weight_init(mean=0.0, std=0.02)
Generator_B
# Out:
# Generator(
#   (pad): ReflectionPad2d((3, 3, 3, 3))
#   (conv1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv3): ConvBlock(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (resnet_blocks): Sequential(
#     (0): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (1): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (2): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (3): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (4): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (5): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#   )
#   (deconv1): DeconvBlock(
#     (deconv): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv2): DeconvBlock(
#     (deconv): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv3): ConvBlock(
#     (conv): Conv2d(32, 3, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
# )

# %% [markdown]
# ##Creating the Discriminator
#
# The Discriminator will consist of the following
# 1. Initialization
# 2. Forward Pass
# 3. Weights
#
# After creating the class, we will create the actuall Discriminator.

# %%
class Discriminator(torch.nn.Module):
    def __init__(self,input_dim,num_filter,output_dim):
        super(Discriminator,self).__init__()

        #Input - NN Layer 1
        conv1 = ConvBlock(input_dim,num_filter,kernel_size=4,stride=2,padding=1,activation='lrelu',batch_norm=False)
        
        #NN Layer 2
        conv2 = ConvBlock(num_filter,num_filter*2,kernel_size=4,stride=2,padding=1,activation='lrelu')
        
        #NN Layer 3
        conv3 = ConvBlock(num_filter*2,num_filter*4,kernel_size=4,stride=2,padding=1,activation='lrelu')
        
        #NN Layer 4
        conv4 = ConvBlock(num_filter*4,num_filter*8,kernel_size=4,stride=1,padding=1,activation='lrelu')
        
        #Output - NN Layer 5
        conv5 = ConvBlock(num_filter*8,output_dim,kernel_size=4,stride=1,padding=1,activation='no_act',batch_norm=False)
        
        
        self.conv_blocks = torch.nn.Sequential(
            conv1,
            conv2,
            conv3,
            conv4,
            conv5
            )
        
    def forward(self,x):
        out = self.conv_blocks(x)
        return out

    #Creating the weights for the Discriminator
    def normal_weight_init(self, mean=0.0, std=0.02):
        for m in self.children():
            if isinstance(m, ConvBlock):
                torch.nn.init.normal_(m.conv.weight.data, mean, std)

# %% [markdown]
# ### Creating the Discriminator and Testing the Neural Network
#
# Similar with the Generator, which requires 2 Neural Networks. We will create 2 Discriminators that compete with each other.

# %% [markdown]
# #### Discriminator A

# %%
Discriminator_A = Discriminator(3, parameters['ndf'], 1).cuda()
Discriminator_A.normal_weight_init(mean=0.0, std=0.02)
Discriminator_A
# Out:
# Discriminator(
#   (conv_blocks): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (4): ConvBlock(
#       (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(1, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#   )
# )

# %% [markdown]
# #### Discriminator B

# %%
Discriminator_B = Discriminator(3, parameters['ndf'], 1).cuda()
Discriminator_B.normal_weight_init(mean=0.0, std=0.02)
Discriminator_B
# Out:
# Discriminator(
#   (conv_blocks): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (4): ConvBlock(
#       (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(1, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#   )
# )

# %% [markdown]
# ## Training Block / DataLoaders
#
# In this block, we will create the actual training block we will be using to train our model.

# %%
train_data_A = DatasetFromFolder(basepath, subfolder='trainA_Male', transform=trans,
                                resize_scale=parameters['resize_size'], 
                                crop_size=parameters['crop_size'], 
                                fliplr=parameters['fliplr'])

train_data_loader_A = torch.utils.data.DataLoader(dataset=train_data_A, 
                                                  batch_size=parameters['batch_size'], 
                                                  num_workers=parameters['num_workers'],
                                                  pin_memory=True,
                                                  shuffle=True)

train_data_B = DatasetFromFolder(basepath, subfolder='trainB_Female', transform=trans,
                                 resize_scale=parameters['resize_size'], 
                                 crop_size=parameters['crop_size'], 
                                 fliplr=True)

train_data_loader_B = torch.utils.data.DataLoader(dataset=train_data_B, 
                                                  batch_size=parameters['batch_size'], 
                                                  num_workers=parameters['num_workers'],
                                                  pin_memory=True,
                                                  shuffle=True)

#Load test data
test_data_A = DatasetFromFolder(basepath, subfolder='testA_Male', transform=trans)

test_data_loader_A = torch.utils.data.DataLoader(dataset=test_data_A, 
                                                 batch_size=parameters['batch_size'], 
                                                 shuffle=False)

test_data_B = DatasetFromFolder(basepath, subfolder='trainB_Female', transform=trans)

test_data_loader_B = torch.utils.data.DataLoader(dataset=test_data_B, 
                                                 batch_size=parameters['batch_size'], 
                                                 shuffle=False)

# %% [markdown]
# ## Retreiving Items
#
# In this block / section we will be retreiving an item for both the real data generated twice. We will also show this data not as an image, but as a Tensor array. We will do this to verify that there are some changes made compared to it's original state.

# %% [markdown]
# ### Test Real Data A

# %%
test_real_A_data = train_data_A.__getitem__(11).unsqueeze(0)
test_real_A_data
# Out:
# tensor([[[[-0.9686, -0.9686, -0.9686,  ..., -0.1059, -0.1922, -0.3176],
#           [-0.9765, -0.9686, -0.9608,  ..., -0.0588, -0.1686, -0.2941],
#           [-0.9765, -0.9686, -0.9529,  ..., -0.0353, -0.1529, -0.2863],
#           ...,
#           [ 0.6235,  0.6471,  0.6627,  ...,  0.9765,  0.9765,  0.9686],
#           [ 0.5843,  0.6235,  0.6627,  ...,  0.9765,  0.9765,  0.9686],
#           [ 0.5529,  0.6000,  0.6549,  ...,  0.9765,  0.9765,  0.9765]],
#
#          [[-0.9686, -0.9686, -0.9686,  ..., -0.1059, -0.1922, -0.3176],
#           [-0.9765, -0.9686, -0.9608,  ..., -0.0588, -0.1686, -0.2941],
#           [-0.9765, -0.9686, -0.9529,  ..., -0.0353, -0.1529, -0.2863],
#           ...,
#           [ 0.6235,  0.6471,  0.6627,  ...,  0.9765,  0.9765,  0.9686],
#           [ 0.5843,  0.6235,  0.6627,  ...,  0.9765,  0.9765,  0.9686],
#           [ 0.5529,  0.6000,  0.6549,  ...,  0.9765,  0.9765,  0.9765]],
#
#          [[-0.9686, -0.9686, -0.9686,  ..., -0.1059, -0.1922, -0.3176],
#           [-0.9765, -0.9686, -0.9608,  ..., -0.0588, -0.1686, -0.2941],
#           [-0.9765, -0.9686, -0.9529,  ..., -0.0353, -0.1529, -0.2863],
#           ...,
#           [ 0.6235,  0.6471,  0.6627,  ...,  0.9765,  0.9765,  0.9686],
#           [ 0.5843,  0.6235,  0.6627,  ...,  0.9765,  0.9765,  0.9686],
#           [ 0.5529,  0.6000,  0.6549,  ...,  0.9765,  0.9765,  0.9765]]]])

# %% [markdown]
# ### Test Real Data B

# %%
test_real_B_data = train_data_B.__getitem__(11).unsqueeze(0)
test_real_B_data
# Out:
# tensor([[[[-0.4824, -0.4431, -0.3647,  ...,  0.3490,  0.7176,  0.9686],
#           [-0.4667, -0.4118, -0.3333,  ...,  0.3333,  0.6314,  0.9451],
#           [-0.4510, -0.3882, -0.3020,  ...,  0.4196,  0.5373,  0.8588],
#           ...,
#           [-0.0431, -0.0353, -0.0275,  ...,  0.9765,  0.9843,  0.9373],
#           [-0.0588, -0.0353, -0.0196,  ...,  0.9608,  0.9843,  0.9529],
#           [-0.0745, -0.0353, -0.0196,  ...,  0.9529,  0.9843,  0.9686]],
#
#          [[-0.7882, -0.7647, -0.7020,  ..., -0.6314, -0.2314,  0.0745],
#           [-0.7882, -0.7569, -0.6863,  ..., -0.6471, -0.3490, -0.0039],
#           [-0.7882, -0.7490, -0.6706,  ..., -0.5686, -0.4667, -0.1373],
#           ...,
#           [-0.6549, -0.6627, -0.6784,  ...,  0.3098,  0.2471,  0.1529],
#           [-0.6706, -0.6627, -0.6706,  ...,  0.3333,  0.2784,  0.1765],
#           [-0.6784, -0.6627, -0.6706,  ...,  0.3569,  0.3020,  0.2078]],
#
#          [[-0.8745, -0.8824, -0.8275,  ..., -0.9059, -0.5765, -0.3098],
#           [-0.8745, -0.8667, -0.8118,  ..., -0.9216, -0.7020, -0.3961],
#           [-0.8745, -0.8510, -0.7882,  ..., -0.8667, -0.8275, -0.5373],
#           ...,
#           [-0.8196, -0.8588, -0.9137,  ..., -0.2000, -0.2706, -0.3725],
#           [-0.8353, -0.8588, -0.8980,  ..., -0.1843, -0.2392, -0.3490],
#           [-0.8510, -0.8588, -0.8980,  ..., -0.1608, -0.2235, -0.3176]]]])

# %% [markdown]
# ## Creating the Optimizer

# %%
Generator_optimizer = torch.optim.Adam(itertools.chain(Generator_A.parameters(),
                                                       Generator_B.parameters()),
                                                       betas=(parameters['beta1'], parameters['beta2']),
                                                       lr=parameters['lgG'])

Discriminator_A_optimizer = torch.optim.Adam(itertools.chain(Discriminator_A.parameters(),
                                                           Discriminator_B.parameters()),
                                                           betas=(parameters['beta1'], parameters['beta2']),
                                                           lr=parameters['lgD'])

Discriminator_B_optimizer = torch.optim.Adam(itertools.chain(Discriminator_A.parameters(),
                                                           Discriminator_B.parameters()),
                                                           betas=(parameters['beta1'], parameters['beta2']),
                                                           lr=parameters['lgD'])

# %% [markdown]
# ## Defining Losses

# %%
MSE_Loss = torch.nn.MSELoss().cuda()
L1_Loss = torch.nn.L1Loss().cuda()

# %%
Discriminator_A_avg_losses = []
Discriminator_B_avg_losses = []
Generator_A_avg_losses = []
Generator_B_avg_losses = []

cycle_A_avg_losses = []
cycle_B_avg_losses = []

# %% [markdown]
# ## Training the model and retreiving Images

# %% [markdown]
# Using the image pool created earliler, we will create a pool of variables which we will be using for training at the next cell block.

# %%
num_pool = 50
fake_A_Pool = ImagePool(num_pool)
fake_B_Pool = ImagePool(num_pool)

step = 0

# %% [markdown]
# We will now run the Training sequence in the block.

# %%
for epoch in range(parameters['num_epochs']):
    Discriminator_A_losses = []
    Discriminator_B_losses = []
    Generator_A_losses = []
    Generator_B_losses = []
    cycle_A_losses = []
    cycle_B_losses = []
    
    # Learing rate decay 
    if(epoch + 1) > parameters['decay_epoch']:
        Discriminatoroptimizer.param_groups[0]['lr'] -= parameters['lgD'] / (parameters['num_epochs'] - parameters['decay_epoch'])
        Discriminator_B_optimizer.param_groups[0]['lr'] -= parameters['lgD'] / (parameters['num_epochs'] - parameters['decay_epoch'])
        G_optimizer.param_groups[0]['lr'] -= parameters['lrG'] / (parameters['num_epochs'] - parameters['decay_epoch'])
        
    
    # training 
    for i, (real_A, real_B) in tqdm(enumerate(zip(train_data_loader_A, train_data_loader_B)), total=len(train_data_loader_A)):
        
        # input image data
        real_A = real_A.to(device)
        real_B = real_B.to(device)
        
        # Train The Generator
        # A --> B
        fake_B = Generator_A(real_A)
        Discriminator_B_fake_decision = Discriminator_B(fake_B)
        Generator_A_loss = MSE_Loss(Discriminator_B_fake_decision, Variable(torch.ones(Discriminator_B_fake_decision.size()).cuda()))
        
        # Forward Cycle Loss
        recon_A = Generator_B(fake_B)
        cycle_A_loss = L1_Loss(recon_A, real_A) * parameters['lambdaA']
        
        # B --> A
        fake_A = Generator_B(real_B)
        Discriminator_fake_decision = Discriminator_A(fake_A)
        Generator_B_loss = MSE_Loss(Discriminator_fake_decision, Variable(torch.ones(Discriminator_fake_decision.size()).cuda()))
        
        # Backward Cycle Loss
        recon_B = Generator_A(fake_A)
        cycle_B_loss = L1_Loss(recon_B, real_B) * parameters['lambdaB']
        
        # Back Propagation
        Generator_loss = Generator_A_loss + Generator_B_loss + cycle_A_loss + cycle_B_loss
        Generator_optimizer.zero_grad()
        Generator_loss.backward()
        Generator_optimizer.step()
        
        
        # Train Discriminator_A 
        Discriminator_real_decision = Discriminator_A(real_A)
        Discriminator_real_loss = MSE_Loss(Discriminator_real_decision, Variable(torch.ones(Discriminator_real_decision.size()).cuda()))
        
        fake_A = fake_A_Pool.query(fake_A)
        
        Discriminator_fake_decision = Discriminator_A(fake_A)
        Discriminator_fake_loss = MSE_Loss(Discriminator_fake_decision, Variable(torch.zeros(Discriminator_fake_decision.size()).cuda()))
        
        # Back propagation
        Discriminator_A_loss = (Discriminator_real_loss + Discriminator_fake_loss) * 0.5
        Discriminator_A_optimizer.zero_grad()
        Discriminator_A_loss.backward()
        Discriminator_A_optimizer.step()
        
        # Train Discriminator_B 
        Discriminator_B_real_decision = Discriminator_B(real_B)
        
        try:
          Discriminator_B_real_loss = MSE_Loss(Discriminator_B_real_decision, Variable(torch.ones(Discriminator_B_fake_decision.size()).cuda()))
        except:
          print(Discriminator_B_real_decision)

        fake_B = fake_B_Pool.query(fake_B)
        
        Discriminator_B_fake_decision = Discriminator_B(fake_B)
        Discriminator_B_fake_loss = MSE_Loss(Discriminator_B_fake_decision, Variable(torch.zeros(Discriminator_B_fake_decision.size()).cuda()))
        
        # Back Propagation
        Discriminator_B_loss = (Discriminator_B_real_loss + Discriminator_B_fake_loss) * 0.5
        Discriminator_B_optimizer.zero_grad()
        Discriminator_B_loss.backward(retain_graph=True)
        Discriminator_B_optimizer.step()
        
        #  Print 


        # loss values
        Discriminator_A_losses.append(Discriminator_A_loss.item())
        Discriminator_B_losses.append(Discriminator_B_loss.item())
        Generator_A_losses.append(Generator_A_loss.item())
        Generator_B_losses.append(Generator_B_loss.item())
        cycle_A_losses.append(cycle_A_loss.item())
        cycle_B_losses.append(cycle_B_loss.item())

        if i%100 == 0:
            print('Epoch [%d/%d], Step [%d/%d], Discriminator_A_losses: %.4f, Discriminator_B_loss: %.4f, Generator_A_loss: %.4f, Generator_B_loss: %.4f'
                  % (epoch+1, parameters['num_epochs'], i+1, len(train_data_loader_A), Discriminator_A_loss.item(), Discriminator_B_loss.item(), Generator_A_loss.item(), Generator_B_loss.item()))
            
        step += 1
        
    Discriminator_A_avg_loss = torch.mean(torch.FloatTensor(Discriminator_A_losses))
    Discriminator_B_avg_loss = torch.mean(torch.FloatTensor(Discriminator_B_losses))
    Generator_A_avg_loss = torch.mean(torch.FloatTensor(Generator_A_losses))
    Generator_B_avg_loss = torch.mean(torch.FloatTensor(Generator_B_losses))
    cycle_A_avg_loss = torch.mean(torch.FloatTensor(cycle_A_losses))
    cycle_B_avg_loss = torch.mean(torch.FloatTensor(cycle_B_losses))

    # Average Loss Values
    Discriminator_A_avg_losses.append(Discriminator_A_avg_loss.item())
    Discriminator_B_avg_losses.append(Discriminator_B_avg_loss.item())
    Generator_A_avg_losses.append(Generator_A_avg_loss.item())
    Generator_B_avg_losses.append(Generator_B_avg_loss.item())
    cycle_A_avg_losses.append(cycle_A_avg_loss.item())
    cycle_B_avg_losses.append(cycle_B_avg_loss.item())
    
    # Test Image Results
    test_real_A = test_real_A_data.cuda()
    test_fake_B = Generator_A(test_real_A)
    test_recon_A = Generator_B(test_fake_B)

    test_real_B = test_real_B_data.cuda()
    test_fake_A = Generator_B(test_real_B)
    test_recon_B = Generator_A(test_fake_A)

    plot_train_result([test_real_A, test_real_B], [test_fake_B, test_fake_A], [test_recon_A, test_recon_B],
                            epoch, save=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [1/100], Step [1/20], Discriminator_A_losses: 0.6622, Discriminator_B_loss: 0.6867, Generator_A_loss: 1.3083, Generator_B_loss: 1.2094
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [2/100], Step [1/20], Discriminator_A_losses: 0.4789, Discriminator_B_loss: 0.3498, Generator_A_loss: 0.6008, Generator_B_loss: 0.8217
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [3/100], Step [1/20], Discriminator_A_losses: 0.1655, Discriminator_B_loss: 0.2199, Generator_A_loss: 0.2961, Generator_B_loss: 0.3673
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [4/100], Step [1/20], Discriminator_A_losses: 0.2040, Discriminator_B_loss: 0.3076, Generator_A_loss: 0.4581, Generator_B_loss: 0.2122
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [5/100], Step [1/20], Discriminator_A_losses: 0.2314, Discriminator_B_loss: 0.2442, Generator_A_loss: 0.3506, Generator_B_loss: 0.1714
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [6/100], Step [1/20], Discriminator_A_losses: 0.2112, Discriminator_B_loss: 0.1835, Generator_A_loss: 0.3123, Generator_B_loss: 0.7736
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [7/100], Step [1/20], Discriminator_A_losses: 0.1968, Discriminator_B_loss: 0.1478, Generator_A_loss: 0.4134, Generator_B_loss: 0.6044
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [8/100], Step [1/20], Discriminator_A_losses: 0.1568, Discriminator_B_loss: 0.1975, Generator_A_loss: 0.4378, Generator_B_loss: 0.6071
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [9/100], Step [1/20], Discriminator_A_losses: 0.1678, Discriminator_B_loss: 0.1989, Generator_A_loss: 0.3334, Generator_B_loss: 0.3704
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [10/100], Step [1/20], Discriminator_A_losses: 0.1473, Discriminator_B_loss: 0.1937, Generator_A_loss: 0.6368, Generator_B_loss: 0.3835
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [11/100], Step [1/20], Discriminator_A_losses: 0.1939, Discriminator_B_loss: 0.2222, Generator_A_loss: 0.4944, Generator_B_loss: 0.2233
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [12/100], Step [1/20], Discriminator_A_losses: 0.2556, Discriminator_B_loss: 0.1401, Generator_A_loss: 0.3957, Generator_B_loss: 1.0261
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [13/100], Step [1/20], Discriminator_A_losses: 0.1851, Discriminator_B_loss: 0.1352, Generator_A_loss: 0.5868, Generator_B_loss: 0.8783
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [14/100], Step [1/20], Discriminator_A_losses: 0.2617, Discriminator_B_loss: 0.1615, Generator_A_loss: 0.6115, Generator_B_loss: 0.0935
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ff80f81d0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ff80f81d0>>
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# Traceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
# AssertionError: can only join a child process
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ff80f81d0>>
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f6079825710>>
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# Traceback (most recent call last):
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f6079825710>>
# Traceback (most recent call last):
#     self._shutdown_workers()
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ff80f81d0>>
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
#     self._shutdown_workers()
# AssertionError: can only join a child process
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Traceback (most recent call last):
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f607be7a9e8>>
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f6079825710>>
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Traceback (most recent call last):
# AssertionError: can only join a child process
#     self._shutdown_workers()
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     self._shutdown_workers()
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f607be7a9e8>>
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# AssertionError: can only join a child process
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     self._shutdown_workers()
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# AssertionError: can only join a child process
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# AssertionError: can only join a child process
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee163fda0>>
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f6079825710>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee163fda0>>
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f607be7a9e8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     self._shutdown_workers()
# Traceback (most recent call last):
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     self._shutdown_workers()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# AssertionError: can only join a child process
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# AssertionError: can only join a child process
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee04e3390>>
# AssertionError: can only join a child process
# Traceback (most recent call last):
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee04e3390>>
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# Traceback (most recent call last):
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f607be7a9e8>>
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     self._shutdown_workers()
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee163fda0>>
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     self._shutdown_workers()
# AssertionError: can only join a child process
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# AssertionError: can only join a child process
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee45d9550>>
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee45d9550>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee04e3390>>
#     self._shutdown_workers()
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# Traceback (most recent call last):
# AssertionError: can only join a child process
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee163fda0>>
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# Traceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# AssertionError: can only join a child process
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     self._shutdown_workers()
# AssertionError: can only join a child process
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee443fac8>>
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee45d9550>>
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     self._shutdown_workers()
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee443fac8>>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# AssertionError: can only join a child process
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     self._shutdown_workers()
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# AssertionError: can only join a child process
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee04e3390>>
# Traceback (most recent call last):
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee443fac8>>
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee42eb780>>
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee42eb780>>
# Traceback (most recent call last):
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#     self._shutdown_workers()
# AssertionError: can only join a child process
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     self._shutdown_workers()
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# AssertionError: can only join a child process
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee42eb780>>
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
# Traceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
# AssertionError: can only join a child process
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee45d9550>>
# AssertionError: can only join a child process
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee443fac8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee42eb780>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [15/100], Step [1/20], Discriminator_A_losses: 0.1066, Discriminator_B_loss: 0.1418, Generator_A_loss: 0.4792, Generator_B_loss: 0.5395
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [16/100], Step [1/20], Discriminator_A_losses: 0.1352, Discriminator_B_loss: 0.1535, Generator_A_loss: 0.4032, Generator_B_loss: 0.4616
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [17/100], Step [1/20], Discriminator_A_losses: 0.2173, Discriminator_B_loss: 0.1517, Generator_A_loss: 0.4572, Generator_B_loss: 0.6701
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [18/100], Step [1/20], Discriminator_A_losses: 0.1650, Discriminator_B_loss: 0.1635, Generator_A_loss: 0.3006, Generator_B_loss: 0.3061
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [19/100], Step [1/20], Discriminator_A_losses: 0.1187, Discriminator_B_loss: 0.1474, Generator_A_loss: 0.9194, Generator_B_loss: 0.5997
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [20/100], Step [1/20], Discriminator_A_losses: 0.1233, Discriminator_B_loss: 0.2181, Generator_A_loss: 0.4520, Generator_B_loss: 0.5905
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [21/100], Step [1/20], Discriminator_A_losses: 0.1015, Discriminator_B_loss: 0.2203, Generator_A_loss: 0.1871, Generator_B_loss: 0.6043
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [22/100], Step [1/20], Discriminator_A_losses: 0.2027, Discriminator_B_loss: 0.3087, Generator_A_loss: 0.1160, Generator_B_loss: 0.1827
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee40995c0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f6079807358>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee45d4588>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee2e46d30>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee76772b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee75244a8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee7345ac8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f5ee71f0dd8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Epoch [23/100], Step [1/20], Discriminator_A_losses: 0.1139, Discriminator_B_loss: 0.1827, Generator_A_loss: 0.8791, Generator_B_loss: 0.3387
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [24/100], Step [1/20], Discriminator_A_losses: 0.1419, Discriminator_B_loss: 0.2374, Generator_A_loss: 0.9092, Generator_B_loss: 0.4563
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [25/100], Step [1/20], Discriminator_A_losses: 0.2477, Discriminator_B_loss: 0.1792, Generator_A_loss: 0.5531, Generator_B_loss: 0.1450
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [26/100], Step [1/20], Discriminator_A_losses: 0.1468, Discriminator_B_loss: 0.2282, Generator_A_loss: 0.3211, Generator_B_loss: 0.4406
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [27/100], Step [1/20], Discriminator_A_losses: 0.1161, Discriminator_B_loss: 0.1623, Generator_A_loss: 0.2314, Generator_B_loss: 0.5690
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [28/100], Step [1/20], Discriminator_A_losses: 0.1909, Discriminator_B_loss: 0.1958, Generator_A_loss: 0.3053, Generator_B_loss: 0.1687
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [29/100], Step [1/20], Discriminator_A_losses: 0.2092, Discriminator_B_loss: 0.1389, Generator_A_loss: 0.4462, Generator_B_loss: 0.9984
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [30/100], Step [1/20], Discriminator_A_losses: 0.1592, Discriminator_B_loss: 0.1319, Generator_A_loss: 0.4545, Generator_B_loss: 0.3125
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [31/100], Step [1/20], Discriminator_A_losses: 0.1818, Discriminator_B_loss: 0.2448, Generator_A_loss: 0.6876, Generator_B_loss: 0.1615
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [32/100], Step [1/20], Discriminator_A_losses: 0.1342, Discriminator_B_loss: 0.1623, Generator_A_loss: 0.4807, Generator_B_loss: 0.4392
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [33/100], Step [1/20], Discriminator_A_losses: 0.2216, Discriminator_B_loss: 0.2649, Generator_A_loss: 0.8280, Generator_B_loss: 0.4232
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [34/100], Step [1/20], Discriminator_A_losses: 0.1759, Discriminator_B_loss: 0.1638, Generator_A_loss: 0.4359, Generator_B_loss: 0.2347
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [35/100], Step [1/20], Discriminator_A_losses: 0.1988, Discriminator_B_loss: 0.2003, Generator_A_loss: 0.3188, Generator_B_loss: 0.1561
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [36/100], Step [1/20], Discriminator_A_losses: 0.1103, Discriminator_B_loss: 0.1514, Generator_A_loss: 0.4013, Generator_B_loss: 0.4120
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [37/100], Step [1/20], Discriminator_A_losses: 0.1500, Discriminator_B_loss: 0.1086, Generator_A_loss: 0.4156, Generator_B_loss: 0.4248
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [38/100], Step [1/20], Discriminator_A_losses: 0.1270, Discriminator_B_loss: 0.2979, Generator_A_loss: 0.1797, Generator_B_loss: 0.3717
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [39/100], Step [1/20], Discriminator_A_losses: 0.2111, Discriminator_B_loss: 0.1362, Generator_A_loss: 0.4231, Generator_B_loss: 0.6136
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [40/100], Step [1/20], Discriminator_A_losses: 0.1403, Discriminator_B_loss: 0.2577, Generator_A_loss: 0.1979, Generator_B_loss: 0.4231
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [41/100], Step [1/20], Discriminator_A_losses: 0.1616, Discriminator_B_loss: 0.1601, Generator_A_loss: 0.4412, Generator_B_loss: 0.3134
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [42/100], Step [1/20], Discriminator_A_losses: 0.1383, Discriminator_B_loss: 0.1853, Generator_A_loss: 0.3508, Generator_B_loss: 0.4709
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [43/100], Step [1/20], Discriminator_A_losses: 0.2731, Discriminator_B_loss: 0.1586, Generator_A_loss: 0.3246, Generator_B_loss: 1.2233
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [44/100], Step [1/20], Discriminator_A_losses: 0.3083, Discriminator_B_loss: 0.2259, Generator_A_loss: 0.6892, Generator_B_loss: 0.1545
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [45/100], Step [1/20], Discriminator_A_losses: 0.1588, Discriminator_B_loss: 0.1890, Generator_A_loss: 0.6501, Generator_B_loss: 0.3724
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [46/100], Step [1/20], Discriminator_A_losses: 0.1606, Discriminator_B_loss: 0.2654, Generator_A_loss: 1.0053, Generator_B_loss: 0.2501
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [47/100], Step [1/20], Discriminator_A_losses: 0.1586, Discriminator_B_loss: 0.1435, Generator_A_loss: 0.2764, Generator_B_loss: 0.4306
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [48/100], Step [1/20], Discriminator_A_losses: 0.1657, Discriminator_B_loss: 0.1417, Generator_A_loss: 0.3224, Generator_B_loss: 0.3611
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [49/100], Step [1/20], Discriminator_A_losses: 0.1902, Discriminator_B_loss: 0.3063, Generator_A_loss: 1.0552, Generator_B_loss: 0.3132
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [50/100], Step [1/20], Discriminator_A_losses: 0.1873, Discriminator_B_loss: 0.1704, Generator_A_loss: 0.3604, Generator_B_loss: 0.4592
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [51/100], Step [1/20], Discriminator_A_losses: 0.1157, Discriminator_B_loss: 0.1558, Generator_A_loss: 0.6549, Generator_B_loss: 0.3120
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [52/100], Step [1/20], Discriminator_A_losses: 0.1328, Discriminator_B_loss: 0.1541, Generator_A_loss: 0.2333, Generator_B_loss: 0.5246
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [53/100], Step [1/20], Discriminator_A_losses: 0.1898, Discriminator_B_loss: 0.1537, Generator_A_loss: 0.3282, Generator_B_loss: 0.6662
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [54/100], Step [1/20], Discriminator_A_losses: 0.1774, Discriminator_B_loss: 0.1649, Generator_A_loss: 0.4199, Generator_B_loss: 0.4268
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [55/100], Step [1/20], Discriminator_A_losses: 0.1635, Discriminator_B_loss: 0.1538, Generator_A_loss: 0.3271, Generator_B_loss: 0.3916
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [56/100], Step [1/20], Discriminator_A_losses: 0.1969, Discriminator_B_loss: 0.2034, Generator_A_loss: 0.6419, Generator_B_loss: 0.6373
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [57/100], Step [1/20], Discriminator_A_losses: 0.1509, Discriminator_B_loss: 0.2322, Generator_A_loss: 0.8826, Generator_B_loss: 0.2454
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [58/100], Step [1/20], Discriminator_A_losses: 0.1923, Discriminator_B_loss: 0.1386, Generator_A_loss: 0.6059, Generator_B_loss: 0.2222
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [59/100], Step [1/20], Discriminator_A_losses: 0.1365, Discriminator_B_loss: 0.2550, Generator_A_loss: 0.8482, Generator_B_loss: 0.3142
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [60/100], Step [1/20], Discriminator_A_losses: 0.1030, Discriminator_B_loss: 0.1884, Generator_A_loss: 0.4071, Generator_B_loss: 0.3688
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [61/100], Step [1/20], Discriminator_A_losses: 0.1684, Discriminator_B_loss: 0.1688, Generator_A_loss: 0.2256, Generator_B_loss: 0.1780
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [62/100], Step [1/20], Discriminator_A_losses: 0.1383, Discriminator_B_loss: 0.2022, Generator_A_loss: 0.6179, Generator_B_loss: 0.3109
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [63/100], Step [1/20], Discriminator_A_losses: 0.1694, Discriminator_B_loss: 0.1489, Generator_A_loss: 0.5061, Generator_B_loss: 0.4451
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [64/100], Step [1/20], Discriminator_A_losses: 0.1389, Discriminator_B_loss: 0.1319, Generator_A_loss: 0.2901, Generator_B_loss: 0.3886
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [65/100], Step [1/20], Discriminator_A_losses: 0.1616, Discriminator_B_loss: 0.1113, Generator_A_loss: 0.3423, Generator_B_loss: 0.3225
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [66/100], Step [1/20], Discriminator_A_losses: 0.2489, Discriminator_B_loss: 0.1498, Generator_A_loss: 0.3248, Generator_B_loss: 0.3701
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [67/100], Step [1/20], Discriminator_A_losses: 0.1405, Discriminator_B_loss: 0.1496, Generator_A_loss: 0.4532, Generator_B_loss: 0.4857
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [68/100], Step [1/20], Discriminator_A_losses: 0.1336, Discriminator_B_loss: 0.1937, Generator_A_loss: 0.4376, Generator_B_loss: 0.3492
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [69/100], Step [1/20], Discriminator_A_losses: 0.1397, Discriminator_B_loss: 0.1456, Generator_A_loss: 0.4159, Generator_B_loss: 0.3564
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [70/100], Step [1/20], Discriminator_A_losses: 0.1631, Discriminator_B_loss: 0.1733, Generator_A_loss: 0.6391, Generator_B_loss: 0.4321
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [71/100], Step [1/20], Discriminator_A_losses: 0.1963, Discriminator_B_loss: 0.1112, Generator_A_loss: 0.3846, Generator_B_loss: 0.4327
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [72/100], Step [1/20], Discriminator_A_losses: 0.1297, Discriminator_B_loss: 0.1390, Generator_A_loss: 0.3901, Generator_B_loss: 0.3670
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [73/100], Step [1/20], Discriminator_A_losses: 0.1077, Discriminator_B_loss: 0.1305, Generator_A_loss: 0.4600, Generator_B_loss: 0.5322
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [74/100], Step [1/20], Discriminator_A_losses: 0.2038, Discriminator_B_loss: 0.1882, Generator_A_loss: 0.1676, Generator_B_loss: 0.1595
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [75/100], Step [1/20], Discriminator_A_losses: 0.4889, Discriminator_B_loss: 0.1632, Generator_A_loss: 0.2509, Generator_B_loss: 0.0558
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [76/100], Step [1/20], Discriminator_A_losses: 0.1394, Discriminator_B_loss: 0.1570, Generator_A_loss: 0.2473, Generator_B_loss: 0.3962
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [77/100], Step [1/20], Discriminator_A_losses: 0.3600, Discriminator_B_loss: 0.1668, Generator_A_loss: 0.5853, Generator_B_loss: 0.0335
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [78/100], Step [1/20], Discriminator_A_losses: 0.1107, Discriminator_B_loss: 0.1757, Generator_A_loss: 0.1845, Generator_B_loss: 0.3413
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [79/100], Step [1/20], Discriminator_A_losses: 0.1329, Discriminator_B_loss: 0.1727, Generator_A_loss: 0.3475, Generator_B_loss: 0.4361
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [80/100], Step [1/20], Discriminator_A_losses: 0.1118, Discriminator_B_loss: 0.1234, Generator_A_loss: 0.5902, Generator_B_loss: 0.4565
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [81/100], Step [1/20], Discriminator_A_losses: 0.1477, Discriminator_B_loss: 0.1463, Generator_A_loss: 0.3543, Generator_B_loss: 0.3733
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [82/100], Step [1/20], Discriminator_A_losses: 0.1602, Discriminator_B_loss: 0.1395, Generator_A_loss: 0.5514, Generator_B_loss: 0.2791
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [83/100], Step [1/20], Discriminator_A_losses: 0.1339, Discriminator_B_loss: 0.2116, Generator_A_loss: 0.8873, Generator_B_loss: 0.4336
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [84/100], Step [1/20], Discriminator_A_losses: 0.1428, Discriminator_B_loss: 0.1544, Generator_A_loss: 0.2918, Generator_B_loss: 0.2311
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [85/100], Step [1/20], Discriminator_A_losses: 0.1697, Discriminator_B_loss: 0.1528, Generator_A_loss: 0.3390, Generator_B_loss: 0.6503
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [86/100], Step [1/20], Discriminator_A_losses: 0.1369, Discriminator_B_loss: 0.1278, Generator_A_loss: 0.3841, Generator_B_loss: 0.4451
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [87/100], Step [1/20], Discriminator_A_losses: 0.1679, Discriminator_B_loss: 0.1395, Generator_A_loss: 0.4200, Generator_B_loss: 0.3268
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [88/100], Step [1/20], Discriminator_A_losses: 0.1377, Discriminator_B_loss: 0.1496, Generator_A_loss: 0.3379, Generator_B_loss: 0.3483
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [89/100], Step [1/20], Discriminator_A_losses: 0.1278, Discriminator_B_loss: 0.1949, Generator_A_loss: 0.2878, Generator_B_loss: 0.2884
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [90/100], Step [1/20], Discriminator_A_losses: 0.1225, Discriminator_B_loss: 0.1763, Generator_A_loss: 0.2894, Generator_B_loss: 0.4156
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [91/100], Step [1/20], Discriminator_A_losses: 0.1832, Discriminator_B_loss: 0.1575, Generator_A_loss: 0.3223, Generator_B_loss: 0.8232
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [92/100], Step [1/20], Discriminator_A_losses: 0.1333, Discriminator_B_loss: 0.1428, Generator_A_loss: 0.3332, Generator_B_loss: 0.3539
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [93/100], Step [1/20], Discriminator_A_losses: 0.1370, Discriminator_B_loss: 0.1801, Generator_A_loss: 0.2776, Generator_B_loss: 0.7497
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [94/100], Step [1/20], Discriminator_A_losses: 0.1531, Discriminator_B_loss: 0.1327, Generator_A_loss: 0.2899, Generator_B_loss: 0.1767
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [95/100], Step [1/20], Discriminator_A_losses: 0.1311, Discriminator_B_loss: 0.7275, Generator_A_loss: 0.8441, Generator_B_loss: 0.3274
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [96/100], Step [1/20], Discriminator_A_losses: 0.1183, Discriminator_B_loss: 0.2174, Generator_A_loss: 0.3046, Generator_B_loss: 0.3690
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [97/100], Step [1/20], Discriminator_A_losses: 0.2307, Discriminator_B_loss: 0.1876, Generator_A_loss: 0.2813, Generator_B_loss: 0.1056
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [98/100], Step [1/20], Discriminator_A_losses: 0.1467, Discriminator_B_loss: 0.2111, Generator_A_loss: 0.2686, Generator_B_loss: 0.2539
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [99/100], Step [1/20], Discriminator_A_losses: 0.2254, Discriminator_B_loss: 0.1736, Generator_A_loss: 0.2717, Generator_B_loss: 1.1757
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch [100/100], Step [1/20], Discriminator_A_losses: 0.1735, Discriminator_B_loss: 0.1444, Generator_A_loss: 0.4077, Generator_B_loss: 0.2893

# %%
""

# %%
all_losses = pd.DataFrame()
all_losses['Discriminator_A_avg_losses'] = Discriminator_A_avg_losses
all_losses['Discriminator_B_avg_losses'] = Discriminator_B_avg_losses
all_losses['Generator_A_avg_losses'] = Generator_A_avg_losses
all_losses['Generator_B_avg_losses'] = Generator_B_avg_losses
all_losses['cycle_A_avg_losses'] = cycle_A_avg_losses
all_losses['cycle_B_avg_losses'] = cycle_B_avg_losses

# %%
                                                                                                                                                                                                                                                                                                                                        print(all_losses)

# %%
# !nvidia-smi

# %%
#torch.cuda.empty_cache()

# %%
PATH = '/content/drive/My Drive/Thinkful/CapstoneIV'

torch.save(Generator_A.state_dict(), PATH)
torch.save(Generator_B.state_dict(), PATH)
torch.save(Discrimninator_A.state_dict(), PATH)
torch.save(Discriminator_B.state_dict(), PATH)
